# %% [markdown]
# # Crawling Web Data
# In this tutorial, you will learn how to write a web crawler to collect data from the Web.
#
# A **web crawler**, also known as a spider or web spider, is an automated software program or bot that systematically browses the World Wide Web, typically for the purpose of indexing and gathering information from web pages. Web crawlers start by visiting one or more seed URLs, and then follow hyperlinks on those pages to discover and fetch additional URLs. This process continues recursively, allowing the crawler to traverse the web and build a comprehensive index of web pages.
#
# Web crawlers play a crucial role in powering search engines like Google, Bing, and Yahoo, as well as other web-based applications such as web archiving, content aggregation, and data mining. They enable users to discover and access information across the vast expanse of the World Wide Web.
#
# We will show step by step how to write a web crawler to crawl wikipedia webpages related to a certain topic.

# %% [markdown]
# ### Import Libraries

# %%
import requests # A powerful HTTP library that allows you to send HTTP requests easily and efficiently.
from bs4 import BeautifulSoup # A Python library used for parsing HTML and XML documents and extracting data from them.

# %% [markdown]
# ### Sending an Http Request

# %%
# Send a GET request to a URL
response = requests.get("https://en.wikipedia.org/wiki/Data_science")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the response content
    print(response.text)
else:
    # Print an error message if the request failed
    print('Error:', response.status_code)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Data science - Wikipedia</title>
# <script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],
# "wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"102a03ec-f6c8-4660-9e25-562cc4f78285","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Data_science","wgTitle":"Data science","wgCurRevisionId":1218194882,"wgRevisionId":1218194882,"wgArticleId":35458904,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Use dmy dates from August 2023","Articles to be expanded from August 2023","All articles to be expanded","Articles using small message boxes","Information science","Computer occupations","Computational fields of study","Data analysis","Data science"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext",
# "wgRelevantPageName":"Data_science","wgRelevantArticleId":35458904,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgULSCurrentAutonym":"English","wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q2374463","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model",
# "platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"skins.vector.user.styles":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","site","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips",
# "ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});</script>
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022">
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta name="ResourceLoaderDynamicStyles" content="">
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022">
# <meta name="generator" content="MediaWiki 1.42.0-wmf.25">
# <meta name="referrer" content="origin">
# <meta name="referrer" content="origin-when-cross-origin">
# <meta name="robots" content="max-image-preview:standard">
# <meta name="format-detection" content="telephone=no">
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/1200px-PIA23792-1600x1200%281%29.jpg">
# <meta property="og:image:width" content="1200">
# <meta property="og:image:height" content="900">
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/800px-PIA23792-1600x1200%281%29.jpg">
# <meta property="og:image:width" content="800">
# <meta property="og:image:height" content="600">
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/640px-PIA23792-1600x1200%281%29.jpg">
# <meta property="og:image:width" content="640">
# <meta property="og:image:height" content="480">
# <meta name="viewport" content="width=1000">
# <meta property="og:title" content="Data science - Wikipedia">
# <meta property="og:type" content="website">
# <link rel="preconnect" href="//upload.wikimedia.org">
# <link rel="alternate" media="only screen and (max-width: 720px)" href="//en.m.wikipedia.org/wiki/Data_science">
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Data_science&amp;action=edit">
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">
# <link rel="icon" href="/static/favicon/wikipedia.ico">
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)">
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd">
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Data_science">
# <link rel="license" href="https://creativecommons.org/licenses/by-sa/4.0/deed.en">
# <link rel="alternate" type="application/atom+xml" title="Wikipedia Atom feed" href="/w/index.php?title=Special:RecentChanges&amp;feed=atom">
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <link rel="dns-prefetch" href="//login.wikimedia.org">
# </head>
# <body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Data_science rootpage-Data_science skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# 	<header class="vector-header mw-header">
# 		<div class="vector-header-start">
# 			<nav class="vector-main-menu-landmark" aria-label="Site" role="navigation">
#
# <div id="vector-main-menu-dropdown" class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right"  >
# 	<input type="checkbox" id="vector-main-menu-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-main-menu-dropdown" class="vector-dropdown-checkbox "  aria-label="Main menu"  >
# 	<label id="vector-main-menu-dropdown-label" for="vector-main-menu-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
#
# <span class="vector-dropdown-label-text">Main menu</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 				<div id="vector-main-menu-unpinned-container" class="vector-unpinned-container">
#
# <div id="vector-main-menu" class="vector-main-menu vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned"
# 	data-feature-name="main-menu-pinned"
# 	data-pinnable-element-id="vector-main-menu"
# 	data-pinned-container-id="vector-main-menu-pinned-container"
# 	data-unpinned-container-id="vector-main-menu-unpinned-container"
# >
# 	<div class="vector-pinnable-header-label">Main menu</div>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">hide</button>
# </div>
#
#
# <div id="p-navigation" class="vector-menu mw-portlet mw-portlet-navigation"  >
# 	<div class="vector-menu-heading">
# 		Navigation
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="n-mainpage-description" class="mw-list-item"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z"><span>Main page</span></a></li><li id="n-contents" class="mw-list-item"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li id="n-currentevents" class="mw-list-item"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li id="n-randompage" class="mw-list-item"><a href="/wiki/Special:Random" title="Visit a randomly selected article [x]" accesskey="x"><span>Random article</span></a></li><li id="n-aboutsite" class="mw-list-item"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li id="n-contactpage" class="mw-list-item"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li id="n-sitesupport" class="mw-list-item"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
#
# <div id="p-interaction" class="vector-menu mw-portlet mw-portlet-interaction"  >
# 	<div class="vector-menu-heading">
# 		Contribute
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="n-help" class="mw-list-item"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li id="n-introduction" class="mw-list-item"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li id="n-portal" class="mw-list-item"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li id="n-recentchanges" class="mw-list-item"><a href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]" accesskey="r"><span>Recent changes</span></a></li><li id="n-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# </div>
#
# 				</div>
#
# 	</div>
# </div>
#
# 		</nav>
#
# <a href="/wiki/Main_Page" class="mw-logo">
# 	<img class="mw-logo-icon" src="/static/images/icons/wikipedia.png" alt="" aria-hidden="true" height="50" width="50">
# 	<span class="mw-logo-container">
# 		<img class="mw-logo-wordmark" alt="Wikipedia" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;">
# 		<img class="mw-logo-tagline" alt="The Free Encyclopedia" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" width="117" height="13" style="width: 7.3125em; height: 0.8125em;">
# 	</span>
# </a>
#
# 		</div>
# 		<div class="vector-header-end">
#
# <div id="p-search" role="search" class="vector-search-box-vue  vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box">
# 	<a href="/wiki/Special:Search" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" id="" title="Search Wikipedia [f]" accesskey="f"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
#
# <span>Search</span>
# 	</a>
# 	<div class="vector-typeahead-search-container">
# 		<div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# 			<form action="/w/index.php" id="searchform" class="cdx-search-input cdx-search-input--has-end-button">
# 				<div id="simpleSearch" class="cdx-search-input__input-wrapper"  data-search-loc="header-moved">
# 					<div class="cdx-text-input cdx-text-input--has-start-icon">
# 						<input
# 							class="cdx-text-input__input"
# 							 type="search" name="search" placeholder="Search Wikipedia" aria-label="Search Wikipedia" autocapitalize="sentences" title="Search Wikipedia [f]" accesskey="f" id="searchInput"
# 							>
# 						<span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# 					</div>
# 					<input type="hidden" name="title" value="Special:Search">
# 				</div>
# 				<button class="cdx-button cdx-search-input__end-button">Search</button>
# 			</form>
# 		</div>
# 	</div>
# </div>
#
# 			<nav class="vector-user-links vector-user-links-wide" aria-label="Personal tools" role="navigation" >
# 	<div class="vector-user-links-main">
#
# <div id="p-vector-user-menu-preferences" class="vector-menu mw-portlet emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="p-vector-user-menu-userpage" class="vector-menu mw-portlet emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
# 	<nav class="vector-client-prefs-landmark" aria-label="Appearance">
#
#
# 	</nav>
#
# <div id="p-vector-user-menu-notifications" class="vector-menu mw-portlet emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="p-vector-user-menu-overflow" class="vector-menu mw-portlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
# 			<li id="pt-createaccount-2" class="user-links-collapsible-item mw-list-item user-links-collapsible-item"><a data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=Data+science" title="You are encouraged to create an account and log in; however, it is not mandatory" class=""><span>Create account</span></a>
# </li>
# <li id="pt-login-2" class="user-links-collapsible-item mw-list-item user-links-collapsible-item"><a data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=Data+science" title="You&#039;re encouraged to log in; however, it&#039;s not mandatory. [o]" accesskey="o" class=""><span>Log in</span></a>
# </li>
#
#
# 		</ul>
#
# 	</div>
# </div>
#
# 	</div>
#
# <div id="vector-user-links-dropdown" class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out"  title="Log in and more options" >
# 	<input type="checkbox" id="vector-user-links-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-user-links-dropdown" class="vector-dropdown-checkbox "  aria-label="Personal tools"  >
# 	<label id="vector-user-links-dropdown-label" for="vector-user-links-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
#
# <span class="vector-dropdown-label-text">Personal tools</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
#
# <div id="p-personal" class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item"  title="User menu" >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="pt-createaccount" class="user-links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Data+science" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a></li><li id="pt-login" class="user-links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Data+science" title="You&#039;re encouraged to log in; however, it&#039;s not mandatory. [o]" accesskey="o"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Log in</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-user-menu-anon-editor" class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor"  >
# 	<div class="vector-menu-heading">
# 		Pages for logged out editors <a href="/wiki/Help:Introduction" aria-label="Learn more about editing"><span>learn more</span></a>
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="pt-anoncontribs" class="mw-list-item"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y"><span>Contributions</span></a></li><li id="pt-anontalk" class="mw-list-item"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n"><span>Talk</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
# 	</div>
# </div>
#
# </nav>
#
# 		</div>
# 	</header>
# </div>
# <div class="mw-page-container">
# 	<div class="mw-page-container-inner">
# 		<div class="vector-sitenotice-container">
# 			<div id="siteNotice"><!-- CentralNotice --></div>
# 		</div>
# 		<div class="vector-column-start">
# 			<div class="vector-main-menu-container">
# 		<div id="mw-navigation">
# 			<nav id="mw-panel" class="vector-main-menu-landmark" aria-label="Site" role="navigation">
# 				<div id="vector-main-menu-pinned-container" class="vector-pinned-container">
#
# 				</div>
# 		</nav>
# 		</div>
# 	</div>
# 	<div class="vector-sticky-pinned-container">
# 				<nav id="mw-panel-toc" role="navigation" aria-label="Contents" data-event-name="ui.sidebar-toc" class="mw-table-of-contents-container vector-toc-landmark">
# 					<div id="vector-toc-pinned-container" class="vector-pinned-container">
# 					<div id="vector-toc" class="vector-toc vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned"
# 	data-feature-name="toc-pinned"
# 	data-pinnable-element-id="vector-toc"
#
#
# >
# 	<h2 class="vector-pinnable-header-label">Contents</h2>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>
# </div>
#
#
# 	<ul class="vector-toc-contents" id="mw-panel-toc-list">
# 		<li id="toc-mw-content-text"
# 			class="vector-toc-list-item vector-toc-level-1">
# 			<a href="#" class="vector-toc-link">
# 				<div class="vector-toc-text">(Top)</div>
# 			</a>
# 		</li>
# 		<li id="toc-Foundations"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#Foundations">
# 			<div class="vector-toc-text">
# 			<span class="vector-toc-numb">1</span>Foundations</div>
# 		</a>
#
# 			<button aria-controls="toc-Foundations-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# 				<span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# 				<span>Toggle Foundations subsection</span>
# 			</button>
#
# 		<ul id="toc-Foundations-sublist" class="vector-toc-list">
# 			<li id="toc-Relationship_to_statistics"
# 			class="vector-toc-list-item vector-toc-level-2">
# 			<a class="vector-toc-link" href="#Relationship_to_statistics">
# 				<div class="vector-toc-text">
# 				<span class="vector-toc-numb">1.1</span>Relationship to statistics</div>
# 			</a>
#
# 			<ul id="toc-Relationship_to_statistics-sublist" class="vector-toc-list">
# 			</ul>
# 		</li>
# 	</ul>
# 	</li>
# 	<li id="toc-Etymology"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#Etymology">
# 			<div class="vector-toc-text">
# 			<span class="vector-toc-numb">2</span>Etymology</div>
# 		</a>
#
# 			<button aria-controls="toc-Etymology-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# 				<span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# 				<span>Toggle Etymology subsection</span>
# 			</button>
#
# 		<ul id="toc-Etymology-sublist" class="vector-toc-list">
# 			<li id="toc-Early_usage"
# 			class="vector-toc-list-item vector-toc-level-2">
# 			<a class="vector-toc-link" href="#Early_usage">
# 				<div class="vector-toc-text">
# 				<span class="vector-toc-numb">2.1</span>Early usage</div>
# 			</a>
#
# 			<ul id="toc-Early_usage-sublist" class="vector-toc-list">
# 			</ul>
# 		</li>
# 		<li id="toc-Modern_usage"
# 			class="vector-toc-list-item vector-toc-level-2">
# 			<a class="vector-toc-link" href="#Modern_usage">
# 				<div class="vector-toc-text">
# 				<span class="vector-toc-numb">2.2</span>Modern usage</div>
# 			</a>
#
# 			<ul id="toc-Modern_usage-sublist" class="vector-toc-list">
# 			</ul>
# 		</li>
# 	</ul>
# 	</li>
# 	<li id="toc-Data_science_and_data_analysis"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#Data_science_and_data_analysis">
# 			<div class="vector-toc-text">
# 			<span class="vector-toc-numb">3</span>Data science and data analysis</div>
# 		</a>
#
# 		<ul id="toc-Data_science_and_data_analysis-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# 	<li id="toc-History"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#History">
# 			<div class="vector-toc-text">
# 			<span class="vector-toc-numb">4</span>History</div>
# 		</a>
#
# 		<ul id="toc-History-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# 	<li id="toc-See_also"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#See_also">
# 			<div class="vector-toc-text">
# 			<span class="vector-toc-numb">5</span>See also</div>
# 		</a>
#
# 		<ul id="toc-See_also-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# 	<li id="toc-References"
# 		class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">
# 		<a class="vector-toc-link" href="#References">
# 			<div class="vector-toc-text">
# 			<span class="vector-toc-numb">6</span>References</div>
# 		</a>
#
# 		<ul id="toc-References-sublist" class="vector-toc-list">
# 		</ul>
# 	</li>
# </ul>
# </div>
#
# 					</div>
# 		</nav>
# 			</div>
# 		</div>
# 		<div class="mw-content-container">
# 			<main id="content" class="mw-body" role="main">
# 				<header class="mw-body-header vector-page-titlebar">
# 					<nav role="navigation" aria-label="Contents" class="vector-toc-landmark">
#
# <div id="vector-page-titlebar-toc" class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left"  >
# 	<input type="checkbox" id="vector-page-titlebar-toc-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-page-titlebar-toc" class="vector-dropdown-checkbox "  aria-label="Toggle the table of contents"  >
# 	<label id="vector-page-titlebar-toc-label" for="vector-page-titlebar-toc-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>
#
# <span class="vector-dropdown-label-text">Toggle the table of contents</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 							<div id="vector-page-titlebar-toc-unpinned-container" class="vector-unpinned-container">
# 			</div>
#
# 	</div>
# </div>
#
# 					</nav>
# 					<h1 id="firstHeading" class="firstHeading mw-first-heading"><span class="mw-page-title-main">Data science</span></h1>
#
# <div id="p-lang-btn" class="vector-dropdown mw-portlet mw-portlet-lang"  >
# 	<input type="checkbox" id="p-lang-btn-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-p-lang-btn" class="vector-dropdown-checkbox mw-interlanguage-selector" aria-label="Go to an article in another language. Available in 48 languages"   >
# 	<label id="p-lang-btn-label" for="p-lang-btn-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-48" aria-hidden="true"  ><span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive"></span>
#
# <span class="vector-dropdown-label-text">48 languages</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
# 		<div class="vector-menu-content">
#
# 			<ul class="vector-menu-content-list">
#
# 				<li class="interlanguage-link interwiki-ar mw-list-item"><a href="https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA" title="علم البيانات – Arabic" lang="ar" hreflang="ar" class="interlanguage-link-target"><span>العربية</span></a></li><li class="interlanguage-link interwiki-az mw-list-item"><a href="https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi" title="Verilənlər elmi – Azerbaijani" lang="az" hreflang="az" class="interlanguage-link-target"><span>Azərbaycanca</span></a></li><li class="interlanguage-link interwiki-bn mw-list-item"><a href="https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%AA%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%A4_%E0%A6%AC%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%9E%E0%A6%BE%E0%A6%A8" title="উপাত্ত বিজ্ঞান – Bangla" lang="bn" hreflang="bn" class="interlanguage-link-target"><span>বাংলা</span></a></li><li class="interlanguage-link interwiki-bg mw-list-item"><a href="https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D0%B8%D1%82%D0%B5" title="Наука за данните – Bulgarian" lang="bg" hreflang="bg" class="interlanguage-link-target"><span>Български</span></a></li><li class="interlanguage-link interwiki-ca mw-list-item"><a href="https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades" title="Ciència de les dades – Catalan" lang="ca" hreflang="ca" class="interlanguage-link-target"><span>Català</span></a></li><li class="interlanguage-link interwiki-cs mw-list-item"><a href="https://cs.wikipedia.org/wiki/Data_science" title="Data science – Czech" lang="cs" hreflang="cs" class="interlanguage-link-target"><span>Čeština</span></a></li><li class="interlanguage-link interwiki-de mw-list-item"><a href="https://de.wikipedia.org/wiki/Data_Science" title="Data Science – German" lang="de" hreflang="de" class="interlanguage-link-target"><span>Deutsch</span></a></li><li class="interlanguage-link interwiki-et mw-list-item"><a href="https://et.wikipedia.org/wiki/Andmeteadus" title="Andmeteadus – Estonian" lang="et" hreflang="et" class="interlanguage-link-target"><span>Eesti</span></a></li><li class="interlanguage-link interwiki-el mw-list-item"><a href="https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD" title="Επιστήμη δεδομένων – Greek" lang="el" hreflang="el" class="interlanguage-link-target"><span>Ελληνικά</span></a></li><li class="interlanguage-link interwiki-es mw-list-item"><a href="https://es.wikipedia.org/wiki/Ciencia_de_datos" title="Ciencia de datos – Spanish" lang="es" hreflang="es" class="interlanguage-link-target"><span>Español</span></a></li><li class="interlanguage-link interwiki-eo mw-list-item"><a href="https://eo.wikipedia.org/wiki/Datum-scienco" title="Datum-scienco – Esperanto" lang="eo" hreflang="eo" class="interlanguage-link-target"><span>Esperanto</span></a></li><li class="interlanguage-link interwiki-eu mw-list-item"><a href="https://eu.wikipedia.org/wiki/Datu_zientzia" title="Datu zientzia – Basque" lang="eu" hreflang="eu" class="interlanguage-link-target"><span>Euskara</span></a></li><li class="interlanguage-link interwiki-fa mw-list-item"><a href="https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7" title="علم داده‌ها – Persian" lang="fa" hreflang="fa" class="interlanguage-link-target"><span>فارسی</span></a></li><li class="interlanguage-link interwiki-fr mw-list-item"><a href="https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es" title="Science des données – French" lang="fr" hreflang="fr" class="interlanguage-link-target"><span>Français</span></a></li><li class="interlanguage-link interwiki-gl mw-list-item"><a href="https://gl.wikipedia.org/wiki/Ciencia_de_datos" title="Ciencia de datos – Galician" lang="gl" hreflang="gl" class="interlanguage-link-target"><span>Galego</span></a></li><li class="interlanguage-link interwiki-ko mw-list-item"><a href="https://ko.wikipedia.org/wiki/%EB%8D%B0%EC% ...
# 			</ul>
# 			<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>
# 		</div>
#
# 	</div>
# </div>
# </header>
# 				<div class="vector-page-toolbar">
# 					<div class="vector-page-toolbar-container">
# 						<div id="left-navigation">
# 							<nav aria-label="Namespaces">
#
# <div id="p-associated-pages" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-nstab-main" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/Data_science" title="View the content page [c]" accesskey="c"><span>Article</span></a></li><li id="ca-talk" class="vector-tab-noicon mw-list-item"><a href="/wiki/Talk:Data_science" rel="discussion" title="Discuss improvements to the content page [t]" accesskey="t"><span>Talk</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="p-variants" class="vector-dropdown emptyPortlet"  >
# 	<input type="checkbox" id="p-variants-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-p-variants" class="vector-dropdown-checkbox " aria-label="Change language variant"   >
# 	<label id="p-variants-label" for="p-variants-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" aria-hidden="true"  ><span class="vector-dropdown-label-text">English</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
#
# <div id="p-variants" class="vector-menu mw-portlet mw-portlet-variants emptyPortlet"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
#
# 		</ul>
#
# 	</div>
# </div>
#
#
# 	</div>
# </div>
#
# 							</nav>
# 						</div>
# 						<div id="right-navigation" class="vector-collapsible">
# 							<nav aria-label="Views">
#
# <div id="p-views" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-view" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/Data_science"><span>Read</span></a></li><li id="ca-edit" class="vector-tab-noicon mw-list-item"><a href="/w/index.php?title=Data_science&amp;action=edit" title="Edit this page [e]" accesskey="e"><span>Edit</span></a></li><li id="ca-history" class="vector-tab-noicon mw-list-item"><a href="/w/index.php?title=Data_science&amp;action=history" title="Past revisions of this page [h]" accesskey="h"><span>View history</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# 							</nav>
#
# 							<nav class="vector-page-tools-landmark" aria-label="Page tools">
#
# <div id="vector-page-tools-dropdown" class="vector-dropdown vector-page-tools-dropdown"  >
# 	<input type="checkbox" id="vector-page-tools-dropdown-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-page-tools-dropdown" class="vector-dropdown-checkbox "  aria-label="Tools"  >
# 	<label id="vector-page-tools-dropdown-label" for="vector-page-tools-dropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" aria-hidden="true"  ><span class="vector-dropdown-label-text">Tools</span>
# 	</label>
# 	<div class="vector-dropdown-content">
#
#
# 									<div id="vector-page-tools-unpinned-container" class="vector-unpinned-container">
#
# <div id="vector-page-tools" class="vector-page-tools vector-pinnable-element">
# 	<div
# 	class="vector-pinnable-header vector-page-tools-pinnable-header vector-pinnable-header-unpinned"
# 	data-feature-name="page-tools-pinned"
# 	data-pinnable-element-id="vector-page-tools"
# 	data-pinned-container-id="vector-page-tools-pinned-container"
# 	data-unpinned-container-id="vector-page-tools-unpinned-container"
# >
# 	<div class="vector-pinnable-header-label">Tools</div>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-page-tools.pin">move to sidebar</button>
# 	<button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-page-tools.unpin">hide</button>
# </div>
#
#
# <div id="p-cactions" class="vector-menu mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items"  title="More options" >
# 	<div class="vector-menu-heading">
# 		Actions
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-more-view" class="selected vector-more-collapsible-item mw-list-item"><a href="/wiki/Data_science"><span>Read</span></a></li><li id="ca-more-edit" class="vector-more-collapsible-item mw-list-item"><a href="/w/index.php?title=Data_science&amp;action=edit" title="Edit this page [e]" accesskey="e"><span>Edit</span></a></li><li id="ca-more-history" class="vector-more-collapsible-item mw-list-item"><a href="/w/index.php?title=Data_science&amp;action=history"><span>View history</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-tb" class="vector-menu mw-portlet mw-portlet-tb"  >
# 	<div class="vector-menu-heading">
# 		General
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="t-whatlinkshere" class="mw-list-item"><a href="/wiki/Special:WhatLinksHere/Data_science" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j"><span>What links here</span></a></li><li id="t-recentchangeslinked" class="mw-list-item"><a href="/wiki/Special:RecentChangesLinked/Data_science" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k"><span>Related changes</span></a></li><li id="t-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u"><span>Upload file</span></a></li><li id="t-specialpages" class="mw-list-item"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q"><span>Special pages</span></a></li><li id="t-permalink" class="mw-list-item"><a href="/w/index.php?title=Data_science&amp;oldid=1218194882" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li id="t-info" class="mw-list-item"><a href="/w/index.php?title=Data_science&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li id="t-cite" class="mw-list-item"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Data_science&amp;id=1218194882&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li id="t-urlshortener" class="mw-list-item"><a href="/w/index.php?title=Special:UrlShortener&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FData_science"><span>Get shortened URL</span></a></li><li id="t-urlshortener-qrcode" class="mw-list-item"><a href="/w/index.php?title=Special:QrCode&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FData_science"><span>Download QR code</span></a></li><li id="t-wikibase" class="mw-list-item"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q2374463" title="Structured data on this page hosted by Wikidata [g]" accesskey="g"><span>Wikidata item</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-coll-print_export" class="vector-menu mw-portlet mw-portlet-coll-print_export"  >
# 	<div class="vector-menu-heading">
# 		Print/export
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="coll-download-as-rl" class="mw-list-item"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Data_science&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li id="t-print" class="mw-list-item"><a href="/w/index.php?title=Data_science&amp;printable=yes" title="Printable version of this page [p]" accesskey="p"><span>Printable version</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# <div id="p-wikibase-otherprojects" class="vector-menu mw-portlet mw-portlet-wikibase-otherprojects"  >
# 	<div class="vector-menu-heading">
# 		In other projects
# 	</div>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li class="wb-otherproject-link wb-otherproject-commons mw-list-item"><a href="https://commons.wikimedia.org/wiki/Category:Data_science" hreflang="en"><span>Wikimedia Commons</span></a></li><li class="wb-otherproject-link wb-otherproject-wikiversity mw-list-item"><a href="https://en.wikiversity.org/wiki/Data_science" hreflang="en"><span>Wikiversity</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
# </div>
#
# 									</div>
#
# 	</div>
# </div>
#
# 							</nav>
# 						</div>
# 					</div>
# 				</div>
# 				<div class="vector-column-end">
# 					<div class="vector-sticky-pinned-container">
# 						<nav class="vector-page-tools-landmark" aria-label="Page tools">
# 							<div id="vector-page-tools-pinned-container" class="vector-pinned-container">
#
# 							</div>
# 		</nav>
# 						<nav class="vector-client-prefs-landmark" aria-label="Appearance">
# 						</nav>
# 					</div>
# 				</div>
# 				<div id="bodyContent" class="vector-body" aria-labelledby="firstHeading" data-mw-ve-target-container>
# 					<div class="vector-body-before-content">
# 							<div class="mw-indicators">
# 		</div>
#
# 						<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>
# 					</div>
# 					<div id="contentSub"><div id="mw-content-subtitle"></div></div>
#
#
# 					<div id="mw-content-text" class="mw-body-content"><div class="mw-content-ltr mw-parser-output" lang="en" dir="ltr"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Interdisciplinary field of study on deriving knowledge and insights from data</div>
# <style data-mw-deduplicate="TemplateStyles:r1033289096">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div role="note" class="hatnote navigation-not-searchable">Not to be confused with <a href="/wiki/Information_science" title="Information science">information science</a>.</div>
# <p class="mw-empty-elt">
# </p>
# <figure class="mw-default-size" typeof="mw:File/Thumb"><a href="/wiki/File:PIA23792-1600x1200(1).jpg" class="mw-file-description"><img src="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/220px-PIA23792-1600x1200%281%29.jpg" decoding="async" width="220" height="165" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/330px-PIA23792-1600x1200%281%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/440px-PIA23792-1600x1200%281%29.jpg 2x" data-file-width="1600" data-file-height="1200" /></a><figcaption>The existence of <a href="/wiki/Comet_NEOWISE" title="Comet NEOWISE">Comet NEOWISE</a> (here depicted as a series of red dots) was discovered by analyzing <a href="/wiki/Astronomical_survey" title="Astronomical survey">astronomical survey</a> data acquired by a <a href="/wiki/Space_telescope" title="Space telescope">space telescope</a>, the <a href="/wiki/Wide-field_Infrared_Survey_Explorer" title="Wide-field Infrared Survey Explorer">Wide-field Infrared Survey Explorer</a>.</figcaption></figure>
# <p><b>Data science</b> is an <a href="/wiki/Interdisciplinary" class="mw-redirect" title="Interdisciplinary">interdisciplinary</a> academic field<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">&#91;1&#93;</a></sup> that uses <a href="/wiki/Statistics" title="Statistics">statistics</a>, <a href="/wiki/Scientific_computing" class="mw-redirect" title="Scientific computing">scientific computing</a>, <a href="/wiki/Scientific_method" title="Scientific method">scientific methods</a>, processes, <a href="/wiki/Algorithm" title="Algorithm">algorithms</a> and systems to extract or extrapolate <a href="/wiki/Knowledge" title="Knowledge">knowledge</a> and insights from potentially noisy, structured, or <a href="/wiki/Unstructured_data" title="Unstructured data">unstructured data</a>.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">&#91;2&#93;</a></sup>
# </p><p>Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">&#91;3&#93;</a></sup> Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.<sup id="cite_ref-4" class="reference"><a href="#cite_note-4">&#91;4&#93;</a></sup>
# </p><p>Data science is "a concept to unify <a href="/wiki/Statistics" title="Statistics">statistics</a>, <a href="/wiki/Data_analysis" title="Data analysis">data analysis</a>, <a href="/wiki/Informatics" title="Informatics">informatics</a>, and their related <a href="/wiki/Scientific_method" title="Scientific method">methods</a>" to "understand and analyze actual <a href="/wiki/Phenomena" class="mw-redirect" title="Phenomena">phenomena</a>" with <a href="/wiki/Data" title="Data">data</a>.<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">&#91;5&#93;</a></sup> It uses techniques and theories drawn from many fields within the context of <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, statistics, <a href="/wiki/Computer_science" title="Computer science">computer science</a>, <a href="/wiki/Information_science" title="Information science">information science</a>, and <a href="/wiki/Domain_knowledge" title="Domain knowledge">domain knowledge</a>.<sup id="cite_ref-:2_6-0" class="reference"><a href="#cite_note-:2-6">&#91;6&#93;</a></sup> However, data science is different from <a href="/wiki/Computer_science" title="Computer science">computer science</a> and information science. <a href="/wiki/Turing_Award" title="Turing Award">Turing Award</a> winner <a href="/wiki/Jim_Gray_(computer_scientist)" title="Jim Gray (computer scientist)">Jim Gray</a> imagined data science as a "fourth paradigm" of science (<a href="/wiki/Empirical_research" title="Empirical research">empirical</a>, <a href="/wiki/Basic_research" title="Basic research">theoretical</a>, <a href="/wiki/Computational_science" title="Computational science">computational</a>, and now data-driven) and asserted that "everything about science is changing because of the impact of <a href="/wiki/Information_technology" title="Information technology">information technology</a>" and the <a href="/wiki/Information_explosion" title="Information explosion">data deluge</a>.<sup id="cite_ref-TansleyTolle2009_7-0" class="reference"><a href="#cite_note-TansleyTolle2009-7">&#91;7&#93;</a></sup><sup id="cite_ref-BellHey2009_8-0" class="reference"><a href="#cite_note-BellHey2009-8">&#91;8&#93;</a></sup>
# </p><p>A <b> data scientist</b> is a professional who creates programming code and combines it with statistical knowledge to create insights from data.<sup id="cite_ref-9" class="reference"><a href="#cite_note-9">&#91;9&#93;</a></sup>
# </p>
# <meta property="mw:PageProp/toc" />
# <h2><span class="mw-headline" id="Foundations">Foundations</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=1" title="Edit section: Foundations"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></h2>
# ...
# <ul><li><a href="/wiki/Data_acquisition" title="Data acquisition">Acquisition</a></li>
# <li><a href="/wiki/Data_augmentation" title="Data augmentation">Augmentation</a></li>
# <li><a href="/wiki/Data_analysis" title="Data analysis">Analysis</a></li>
# <li><a href="/wiki/Data_archaeology" title="Data archaeology">Archaeology</a></li>
# <li><a href="/wiki/Big_data" title="Big data">Big</a></li>
# <li><a href="/wiki/Data_cleansing" title="Data cleansing">Cleansing</a></li>
# <li><a href="/wiki/Data_collection" title="Data collection">Collection</a></li>
# <li><a href="/wiki/Data_compression" title="Data compression">Compression</a></li>
# <li><a href="/wiki/Data_corruption" title="Data corruption">Corruption</a></li>
# <li><a href="/wiki/Data_curation" title="Data curation">Curation</a></li>
# <li><a href="/wiki/Data_degradation" title="Data degradation">Degradation</a></li>
# <li><a href="/wiki/Data_editing" title="Data editing">Editing</a></li>
# <li><a href="/wiki/Extract,_transform,_load" title="Extract, transform, load">ETL</a>/<a href="/wiki/Extract,_load,_transform" title="Extract, load, transform">ELT</a>
# <ul><li><a href="/wiki/Data_extraction" title="Data extraction">Extract</a></li>
# <li><a href="/wiki/Data_transformation" class="mw-redirect" title="Data transformation">Transform</a></li>
# <li><a href="/wiki/Data_loading" title="Data loading">Load</a></li></ul></li>
# <li><a href="/wiki/Data_farming" title="Data farming">Farming</a></li>
# <li><a href="/wiki/Data_format_management" title="Data format management">Format management</a></li>
# <li><a href="/wiki/Data_fusion" title="Data fusion">Fusion</a></li>
# <li><a href="/wiki/Data_integration" title="Data integration">Integration</a></li>
# <li><a href="/wiki/Data_integrity" title="Data integrity">Integrity</a></li>
# <li><a href="/wiki/Data_library" class="mw-redirect" title="Data library">Library</a></li>
# <li><a href="/wiki/Data_lineage" title="Data lineage">Lineage</a></li>
# <li><a href="/wiki/Data_loss" title="Data loss">Loss</a></li>
# <li><a href="/wiki/Data_management" title="Data management">Management</a></li>
# <li><a href="/wiki/Data_migration" title="Data migration">Migration</a></li>
# <li><a href="/wiki/Data_mining" title="Data mining">Mining</a></li>
# <li><a href="/wiki/Data_philanthropy" title="Data philanthropy">Philanthropy</a></li>
# <li><a href="/wiki/Data_pre-processing" class="mw-redirect" title="Data pre-processing">Pre-processing</a></li>
# <li><a href="/wiki/Data_preservation" title="Data preservation">Preservation</a></li>
# <li><a href="/wiki/Data_processing" title="Data processing">Processing</a></li>
# <li><a href="/wiki/Information_privacy" title="Information privacy">Protection (privacy)</a></li>
# <li><a href="/wiki/Data_publishing" title="Data publishing">Publishing</a></li>
# <li><a href="/wiki/Data_recovery" title="Data recovery">Recovery</a></li>
# <li><a href="/wiki/Data_reduction" title="Data reduction">Reduction</a></li>
# <li><a href="/wiki/Data_retention" title="Data retention">Retention</a></li>
# <li><a href="/wiki/Data_quality" title="Data quality">Quality</a></li>
# <li><a class="mw-selflink selflink">Science</a></li>
# <li><a href="/wiki/Data_scraping" title="Data scraping">Scraping</a></li>
# <li><a href="/wiki/Data_scrubbing" title="Data scrubbing">Scrubbing</a></li>
# <li><a href="/wiki/Data_security" title="Data security">Security</a></li>
# <li><a href="/wiki/Data_steward" title="Data steward">Stewardship</a></li>
# <li><a href="/wiki/Data_storage" title="Data storage">Storage</a></li>
# <li><a href="/wiki/Data_synchronization" title="Data synchronization">Synchronization</a></li>
# <li><a href="/wiki/Data_validation" title="Data validation">Validation</a></li>
# <li><a href="/wiki/Data_warehouse" title="Data warehouse">Warehouse</a></li>
# <li><a href="/wiki/Data_wrangling" title="Data wrangling">Wrangling/munging</a></li></ul>
# </div></td></tr></tbody></table></div>
# <!--
# NewPP limit report
# Parsed by mw‐web.eqiad.main‐76b84f4cc8‐c5tdf
# Cached time: 20240410091150
# Cache expiry: 2592000
# Reduced expiry: false
# Complications: [vary‐revision‐sha1, show‐toc]
# CPU time usage: 0.561 seconds
# Real time usage: 0.708 seconds
# Preprocessor visited node count: 2300/1000000
# Post‐expand include size: 83000/2097152 bytes
# Template argument size: 1079/2097152 bytes
# Highest expansion depth: 12/100
# Expensive parser function count: 4/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 158242/5000000 bytes
# Lua time usage: 0.386/10.000 seconds
# Lua memory usage: 5560287/52428800 bytes
# Number of Wikibase entities loaded: 0/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  624.896      1 -total
#  52.64%  328.921      1 Template:Reflist
#  23.15%  144.638     10 Template:Cite_journal
#  13.49%   84.304      1 Template:Data
#  13.13%   82.056      1 Template:Navbox
#  13.01%   81.278      1 Template:Short_description
#  12.31%   76.928     18 Template:Cite_web
#  10.99%   68.699      1 Template:Expand_section
#  10.59%   66.164      1 Template:Ambox
#   7.86%   49.145      2 Template:Pagetype
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:35458904-0!canonical and timestamp 20240410091150 and revision id 1218194882. Rendering was triggered because: page-view
#  -->
# </div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" width="1" height="1" style="border: none; position: absolute;"></noscript>
# <div class="printfooter" data-nosnippet="">Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Data_science&amp;oldid=1218194882">https://en.wikipedia.org/w/index.php?title=Data_science&amp;oldid=1218194882</a>"</div></div>
# 					<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Information_science" title="Category:Information science">Information science</a></li><li><a href="/wiki/Category:Computer_occupations" title="Category:Computer occupations">Computer occupations</a></li><li><a href="/wiki/Category:Computational_fields_of_study" title="Category:Computational fields of study">Computational fields of study</a></li><li><a href="/wiki/Category:Data_analysis" title="Category:Data analysis">Data analysis</a></li><li><a href="/wiki/Category:Data_science" title="Category:Data science">Data science</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">Articles with short description</a></li><li><a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">Short description is different from Wikidata</a></li><li><a href="/wiki/Category:Use_dmy_dates_from_August_2023" title="Category:Use dmy dates from August 2023">Use dmy dates from August 2023</a></li><li><a href="/wiki/Category:Articles_to_be_expanded_from_August_2023" title="Category:Articles to be expanded from August 2023">Articles to be expanded from August 2023</a></li><li><a href="/wiki/Category:All_articles_to_be_expanded" title="Category:All articles to be expanded">All articles to be expanded</a></li><li><a href="/wiki/Category:Articles_using_small_message_boxes" title="Category:Articles using small message boxes">Articles using small message boxes</a></li></ul></div></div>
# 				</div>
# 			</main>
#
# 		</div>
# 		<div class="mw-footer-container">
#
# <footer id="footer" class="mw-footer" role="contentinfo" >
# 	<ul id="footer-info">
# 	<li id="footer-info-lastmod"> This page was last edited on 10 April 2024, at 09:11<span class="anonymous-show">&#160;(UTC)</span>.</li>
# 	<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License">Creative Commons Attribution-ShareAlike License 4.0</a><a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" style="display:none;"></a>;
# additional terms may apply. By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
#
# 	<ul id="footer-places">
# 	<li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy policy</a></li>
# 	<li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# 	<li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# 	<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 	<li id="footer-places-wm-codeofconduct"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">Code of Conduct</a></li>
# 	<li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# 	<li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# 	<li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">Cookie statement</a></li>
# 	<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Data_science&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# </ul>
#
# 	<ul id="footer-icons" class="noprint">
# 	<li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation" loading="lazy" /></a></li>
# 	<li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img src="/static/images/footer/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88" height="31" loading="lazy"></a></li>
# </ul>
#
# </footer>
#
# 		</div>
# 	</div>
# </div>
# <div class="vector-settings" id="p-dock-bottom">
# 	<ul>
# 		<li>
# 		<button class="cdx-button cdx-button--icon-only vector-limited-width-toggle" id=""><span class="vector-icon mw-ui-icon-fullScreen mw-ui-icon-wikimedia-fullScreen"></span>
#
# <span>Toggle limited content width</span>
# </button>
# </li>
# 	</ul>
# </div>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-7fff68c477-7m8w2","wgBackendResponseTime":185,"wgPageParseReport":{"limitreport":{"cputime":"0.561","walltime":"0.708","ppvisitednodes":{"value":2300,"limit":1000000},"postexpandincludesize":{"value":83000,"limit":2097152},"templateargumentsize":{"value":1079,"limit":2097152},"expansiondepth":{"value":12,"limit":100},"expensivefunctioncount":{"value":4,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":158242,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  624.896      1 -total"," 52.64%  328.921      1 Template:Reflist"," 23.15%  144.638     10 Template:Cite_journal"," 13.49%   84.304      1 Template:Data"," 13.13%   82.056      1 Template:Navbox"," 13.01%   81.278      1 Template:Short_description"," 12.31%   76.928     18 Template:Cite_web"," 10.99%   68.699      1 Template:Expand_section"," 10.59%   66.164      1 Template:Ambox","  7.86%   49.145      2 Template:Pagetype"]},"scribunto":{"limitreport-timeusage":{"value":"0.386","limit":"10.000"},"limitreport-memusage":{"value":5560287,"limit":52428800}},"cachereport":{"origin":"mw-web.eqiad.main-76b84f4cc8-c5tdf","timestamp":"20240410091150","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Data science","url":"https:\/\/en.wikipedia.org\/wiki\/Data_science","sameAs":"http:\/\/www.wikidata.org\/entity\/Q2374463","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q2374463","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2012-04-11T17:34:10Z","dateModified":"2024-04-10T09:11:24Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/4\/45\/PIA23792-1600x1200%281%29.jpg","headline":"interdisciplinary field of study focused on deriving knowledge and insights from data"}</script>
# </body>
# </html>

# %% [markdown]
# ### Use BeautifulSoup to Extract Information from the Webpage

# %%
# Send a GET request to a URL
response = requests.get("https://en.wikipedia.org/wiki/Data_science")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract and print the title of the web page
    title = soup.title # Returns a node in the HTML document tree
    print(title) # html code of the node
    print(title.text) # .text extracts the text of the node

    # Find and print all links on the web page
    links = soup.find_all('a')
    for link in links:
        print(link) # Each link is an <a> node
        try:
            print(link['href']) # The href attributes is the destination url
        except:
            pass # In case some link does not have href.
        print()
else:
    # Print an error message if the request failed
    print('Error:', response.status_code)
# Out:
# <title>Data science - Wikipedia</title>
# Data science - Wikipedia
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# #bodyContent
#
# <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>
# /wiki/Main_Page
#
# <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>
# /wiki/Wikipedia:Contents
#
# <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>
# /wiki/Portal:Current_events
#
# <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>
# /wiki/Special:Random
#
# <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>
# /wiki/Wikipedia:About
#
# <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
#
# <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a>
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
#
# <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a>
# /wiki/Help:Contents
#
# <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a>
# /wiki/Help:Introduction
#
# <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a>
# /wiki/Wikipedia:Community_portal
#
# <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a>
# /wiki/Special:RecentChanges
#
# <a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a>
# /wiki/Wikipedia:File_upload_wizard
#
# <a class="mw-logo" href="/wiki/Main_Page">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
# </span>
# </a>
# /wiki/Main_Page
#
# <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Special:Search" id="" title="Search Wikipedia [f]"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
# <span>Search</span>
# </a>
# /wiki/Special:Search
#
# <a class="" data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=Data+science" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a>
# /w/index.php?title=Special:CreateAccount&returnto=Data+science
#
# <a accesskey="o" class="" data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=Data+science" title="You're encouraged to log in; however, it's not mandatory. [o]"><span>Log in</span></a>
# /w/index.php?title=Special:UserLogin&returnto=Data+science
#
# <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Data+science" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a>
# /w/index.php?title=Special:CreateAccount&returnto=Data+science
#
# <a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Data+science" title="You're encouraged to log in; however, it's not mandatory. [o]"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Log in</span></a>
# /w/index.php?title=Special:UserLogin&returnto=Data+science
#
# <a aria-label="Learn more about editing" href="/wiki/Help:Introduction"><span>learn more</span></a>
# /wiki/Help:Introduction
#
# <a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]"><span>Contributions</span></a>
# /wiki/Special:MyContributions
#
# <a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]"><span>Talk</span></a>
# /wiki/Special:MyTalk
#
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">(Top)</div>
# </a>
# #
#
# <a class="vector-toc-link" href="#Foundations">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>Foundations</div>
# </a>
# #Foundations
#
# <a class="vector-toc-link" href="#Relationship_to_statistics">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1.1</span>Relationship to statistics</div>
# </a>
# #Relationship_to_statistics
#
# <a class="vector-toc-link" href="#Etymology">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>Etymology</div>
# </a>
# #Etymology
#
# <a class="vector-toc-link" href="#Early_usage">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2.1</span>Early usage</div>
# </a>
# #Early_usage
#
# <a class="vector-toc-link" href="#Modern_usage">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2.2</span>Modern usage</div>
# </a>
# #Modern_usage
#
# <a class="vector-toc-link" href="#Data_science_and_data_analysis">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>Data science and data analysis</div>
# </a>
# #Data_science_and_data_analysis
#
# <a class="vector-toc-link" href="#History">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>History</div>
# </a>
# #History
#
# <a class="vector-toc-link" href="#See_also">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">5</span>See also</div>
# </a>
# #See_also
#
# <a class="vector-toc-link" href="#References">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6</span>References</div>
# </a>
# #References
#
# <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA" hreflang="ar" lang="ar" title="علم البيانات – Arabic"><span>العربية</span></a>
# https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA
#
# <a class="interlanguage-link-target" href="https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi" hreflang="az" lang="az" title="Verilənlər elmi – Azerbaijani"><span>Azərbaycanca</span></a>
# https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi
#
# <a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%AA%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%A4_%E0%A6%AC%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%9E%E0%A6%BE%E0%A6%A8" hreflang="bn" lang="bn" title="উপাত্ত বিজ্ঞান – Bangla"><span>বাংলা</span></a>
# https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%AA%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%A4_%E0%A6%AC%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%9E%E0%A6%BE%E0%A6%A8
#
# <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D0%B8%D1%82%D0%B5" hreflang="bg" lang="bg" title="Наука за данните – Bulgarian"><span>Български</span></a>
# https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D0%B8%D1%82%D0%B5
#
# <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades" hreflang="ca" lang="ca" title="Ciència de les dades – Catalan"><span>Català</span></a>
# https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades
#
# <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/Data_science" hreflang="cs" lang="cs" title="Data science – Czech"><span>Čeština</span></a>
# https://cs.wikipedia.org/wiki/Data_science
#
# <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Data_Science" hreflang="de" lang="de" title="Data Science – German"><span>Deutsch</span></a>
# https://de.wikipedia.org/wiki/Data_Science
#
# <a class="interlanguage-link-target" href="https://et.wikipedia.org/wiki/Andmeteadus" hreflang="et" lang="et" title="Andmeteadus – Estonian"><span>Eesti</span></a>
# https://et.wikipedia.org/wiki/Andmeteadus
#
# <a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD" hreflang="el" lang="el" title="Επιστήμη δεδομένων – Greek"><span>Ελληνικά</span></a>
# https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD
#
# <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Ciencia_de_datos" hreflang="es" lang="es" title="Ciencia de datos – Spanish"><span>Español</span></a>
# https://es.wikipedia.org/wiki/Ciencia_de_datos
#
# <a class="interlanguage-link-target" href="https://eo.wikipedia.org/wiki/Datum-scienco" hreflang="eo" lang="eo" title="Datum-scienco – Esperanto"><span>Esperanto</span></a>
# https://eo.wikipedia.org/wiki/Datum-scienco
#
# <a class="interlanguage-link-target" href="https://eu.wikipedia.org/wiki/Datu_zientzia" hreflang="eu" lang="eu" title="Datu zientzia – Basque"><span>Euskara</span></a>
# https://eu.wikipedia.org/wiki/Datu_zientzia
#
# <a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7" hreflang="fa" lang="fa" title="علم داده‌ها – Persian"><span>فارسی</span></a>
# https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7
#
# <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es" hreflang="fr" lang="fr" title="Science des données – French"><span>Français</span></a>
# https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es
#
# <a class="interlanguage-link-target" href="https://gl.wikipedia.org/wiki/Ciencia_de_datos" hreflang="gl" lang="gl" title="Ciencia de datos – Galician"><span>Galego</span></a>
# https://gl.wikipedia.org/wiki/Ciencia_de_datos
#
# <a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4" hreflang="ko" lang="ko" title="데이터 사이언스 – Korean"><span>한국어</span></a>
# https://ko.wikipedia.org/wiki/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4
#
# <a class="interlanguage-link-target" href="https://hy.wikipedia.org/wiki/%D5%8F%D5%BE%D5%B5%D5%A1%D5%AC%D5%B6%D5%A5%D6%80%D5%AB_%D5%A3%D5%AB%D5%BF%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6" hreflang="hy" lang="hy" title="Տվյալների գիտություն – Armenian"><span>Հայերեն</span></a>
# https://hy.wikipedia.org/wiki/%D5%8F%D5%BE%D5%B5%D5%A1%D5%AC%D5%B6%D5%A5%D6%80%D5%AB_%D5%A3%D5%AB%D5%BF%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6
#
# <a class="interlanguage-link-target" href="https://hi.wikipedia.org/wiki/%E0%A4%86%E0%A4%81%E0%A4%95%E0%A4%A1%E0%A4%BC%E0%A4%BE_%E0%A4%B5%E0%A4%BF%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%A8" hreflang="hi" lang="hi" title="आँकड़ा विज्ञान – Hindi"><span>हिन्दी</span></a>
# https://hi.wikipedia.org/wiki/%E0%A4%86%E0%A4%81%E0%A4%95%E0%A4%A1%E0%A4%BC%E0%A4%BE_%E0%A4%B5%E0%A4%BF%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%A8
#
# <a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Ilmu_data" hreflang="id" lang="id" title="Ilmu data – Indonesian"><span>Bahasa Indonesia</span></a>
# https://id.wikipedia.org/wiki/Ilmu_data
#
# <a class="interlanguage-link-target" href="https://zu.wikipedia.org/wiki/INzululwazi_yeMininingo" hreflang="zu" lang="zu" title="INzululwazi yeMininingo – Zulu"><span>IsiZulu</span></a>
# https://zu.wikipedia.org/wiki/INzululwazi_yeMininingo
#
# <a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Scienza_dei_dati" hreflang="it" lang="it" title="Scienza dei dati – Italian"><span>Italiano</span></a>
# https://it.wikipedia.org/wiki/Scienza_dei_dati
#
# <a class="interlanguage-link-target" href="https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%A2_%D7%94%D7%A0%D7%AA%D7%95%D7%A0%D7%99%D7%9D" hreflang="he" lang="he" title="מדע הנתונים – Hebrew"><span>עברית</span></a>
# https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%A2_%D7%94%D7%A0%D7%AA%D7%95%D7%A0%D7%99%D7%9D
#
# <a class="interlanguage-link-target" href="https://kn.wikipedia.org/wiki/%E0%B2%A6%E0%B2%A4%E0%B3%8D%E0%B2%A4%E0%B2%BE%E0%B2%82%E0%B2%B6_%E0%B2%B5%E0%B2%BF%E0%B2%9C%E0%B3%8D%E0%B2%9E%E0%B2%BE%E0%B2%A8" hreflang="kn" lang="kn" title="ದತ್ತಾಂಶ ವಿಜ್ಞಾನ – Kannada"><span>ಕನ್ನಡ</span></a>
# https://kn.wikipedia.org/wiki/%E0%B2%A6%E0%B2%A4%E0%B3%8D%E0%B2%A4%E0%B2%BE%E0%B2%82%E0%B2%B6_%E0%B2%B5%E0%B2%BF%E0%B2%9C%E0%B3%8D%E0%B2%9E%E0%B2%BE%E0%B2%A8
#
# <a class="interlanguage-link-target" href="https://kk.wikipedia.org/wiki/%D0%94%D0%B5%D1%80%D0%B5%D0%BA%D1%82%D0%B5%D1%80_%D1%82%D1%83%D1%80%D0%B0%D0%BB%D1%8B_%D2%93%D1%8B%D0%BB%D1%8B%D0%BC" hreflang="kk" lang="kk" title="Деректер туралы ғылым – Kazakh"><span>Қазақша</span></a>
# https://kk.wikipedia.org/wiki/%D0%94%D0%B5%D1%80%D0%B5%D0%BA%D1%82%D0%B5%D1%80_%D1%82%D1%83%D1%80%D0%B0%D0%BB%D1%8B_%D2%93%D1%8B%D0%BB%D1%8B%D0%BC
#
# <a class="interlanguage-link-target" href="https://lv.wikipedia.org/wiki/Datu_m%C4%81c%C4%ABba" hreflang="lv" lang="lv" title="Datu mācība – Latvian"><span>Latviešu</span></a>
# https://lv.wikipedia.org/wiki/Datu_m%C4%81c%C4%ABba
#
# <a class="interlanguage-link-target" href="https://mk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%BF%D0%BE%D0%B4%D0%B0%D1%82%D0%BE%D1%86%D0%B8%D1%82%D0%B5" hreflang="mk" lang="mk" title="Наука за податоците – Macedonian"><span>Македонски</span></a>
# https://mk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%BF%D0%BE%D0%B4%D0%B0%D1%82%D0%BE%D1%86%D0%B8%D1%82%D0%B5
#
# <a class="interlanguage-link-target" href="https://ms.wikipedia.org/wiki/Sains_data" hreflang="ms" lang="ms" title="Sains data – Malay"><span>Bahasa Melayu</span></a>
# https://ms.wikipedia.org/wiki/Sains_data
#
# <a class="interlanguage-link-target" href="https://my.wikipedia.org/wiki/%E1%80%A1%E1%80%81%E1%80%BB%E1%80%80%E1%80%BA%E1%80%A1%E1%80%9C%E1%80%80%E1%80%BA%E1%80%9E%E1%80%AD%E1%80%95%E1%80%B9%E1%80%95%E1%80%B6%E1%80%95%E1%80%8A%E1%80%AC" hreflang="my" lang="my" title="အချက်အလက်သိပ္ပံပညာ – Burmese"><span>မြန်မာဘာသာ</span></a>
# https://my.wikipedia.org/wiki/%E1%80%A1%E1%80%81%E1%80%BB%E1%80%80%E1%80%BA%E1%80%A1%E1%80%9C%E1%80%80%E1%80%BA%E1%80%9E%E1%80%AD%E1%80%95%E1%80%B9%E1%80%95%E1%80%B6%E1%80%95%E1%80%8A%E1%80%AC
#
# <a class="interlanguage-link-target" href="https://nl.wikipedia.org/wiki/Datawetenschap" hreflang="nl" lang="nl" title="Datawetenschap – Dutch"><span>Nederlands</span></a>
# https://nl.wikipedia.org/wiki/Datawetenschap
#
# <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9" hreflang="ja" lang="ja" title="データサイエンス – Japanese"><span>日本語</span></a>
# https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9
#
# <a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Datavitenskap" hreflang="nb" lang="nb" title="Datavitenskap – Norwegian Bokmål"><span>Norsk bokmål</span></a>
# https://no.wikipedia.org/wiki/Datavitenskap
#
# <a class="interlanguage-link-target" href="https://uz.wikipedia.org/wiki/Ma%CA%BClumotlar_ombori" hreflang="uz" lang="uz" title="Maʼlumotlar ombori – Uzbek"><span>Oʻzbekcha / ўзбекча</span></a>
# https://uz.wikipedia.org/wiki/Ma%CA%BClumotlar_ombori
#
# <a class="interlanguage-link-target" href="https://pa.wikipedia.org/wiki/%E0%A8%A1%E0%A8%BE%E0%A8%9F%E0%A8%BE_%E0%A8%B8%E0%A8%BE%E0%A8%87%E0%A9%B0%E0%A8%B8" hreflang="pa" lang="pa" title="ਡਾਟਾ ਸਾਇੰਸ – Punjabi"><span>ਪੰਜਾਬੀ</span></a>
# https://pa.wikipedia.org/wiki/%E0%A8%A1%E0%A8%BE%E0%A8%9F%E0%A8%BE_%E0%A8%B8%E0%A8%BE%E0%A8%87%E0%A9%B0%E0%A8%B8
#
# <a class="interlanguage-link-target" href="https://pl.wikipedia.org/wiki/Danologia" hreflang="pl" lang="pl" title="Danologia – Polish"><span>Polski</span></a>
# https://pl.wikipedia.org/wiki/Danologia
#
# <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Ci%C3%AAncia_de_dados" hreflang="pt" lang="pt" title="Ciência de dados – Portuguese"><span>Português</span></a>
# https://pt.wikipedia.org/wiki/Ci%C3%AAncia_de_dados
#
# <a class="interlanguage-link-target" href="https://qu.wikipedia.org/wiki/Willakuy_hamut%27ay" hreflang="qu" lang="qu" title="Willakuy hamut'ay – Quechua"><span>Runa Simi</span></a>
# https://qu.wikipedia.org/wiki/Willakuy_hamut%27ay
#
# <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85" hreflang="ru" lang="ru" title="Наука о данных – Russian"><span>Русский</span></a>
# https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85
#
# <a class="interlanguage-link-target" href="https://simple.wikipedia.org/wiki/Data_science" hreflang="en-simple" lang="en-simple" title="Data science – Simple English"><span>Simple English</span></a>
# https://simple.wikipedia.org/wiki/Data_science
#
# <a class="interlanguage-link-target" href="https://sr.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%BF%D0%BE%D0%B4%D0%B0%D1%86%D0%B8%D0%BC%D0%B0" hreflang="sr" lang="sr" title="Наука о подацима – Serbian"><span>Српски / srpski</span></a>
# https://sr.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%BF%D0%BE%D0%B4%D0%B0%D1%86%D0%B8%D0%BC%D0%B0
#
# <a class="interlanguage-link-target" href="https://fi.wikipedia.org/wiki/Datatiede" hreflang="fi" lang="fi" title="Datatiede – Finnish"><span>Suomi</span></a>
# https://fi.wikipedia.org/wiki/Datatiede
#
# <a class="interlanguage-link-target" href="https://ta.wikipedia.org/wiki/%E0%AE%A4%E0%AE%B0%E0%AE%B5%E0%AF%81_%E0%AE%85%E0%AE%B1%E0%AE%BF%E0%AE%B5%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D" hreflang="ta" lang="ta" title="தரவு அறிவியல் – Tamil"><span>தமிழ்</span></a>
# https://ta.wikipedia.org/wiki/%E0%AE%A4%E0%AE%B0%E0%AE%B5%E0%AF%81_%E0%AE%85%E0%AE%B1%E0%AE%BF%E0%AE%B5%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D
#
# <a class="interlanguage-link-target" href="https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%97%E0%B8%A2%E0%B8%B2%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%82%E0%B9%89%E0%B8%AD%E0%B8%A1%E0%B8%B9%E0%B8%A5" hreflang="th" lang="th" title="วิทยาการข้อมูล – Thai"><span>ไทย</span></a>
# https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%97%E0%B8%A2%E0%B8%B2%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%82%E0%B9%89%E0%B8%AD%E0%B8%A1%E0%B8%B9%E0%B8%A5
#
# <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/Veri_bilimi" hreflang="tr" lang="tr" title="Veri bilimi – Turkish"><span>Türkçe</span></a>
# https://tr.wikipedia.org/wiki/Veri_bilimi
#
# <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BF%D1%80%D0%BE_%D0%B4%D0%B0%D0%BD%D1%96" hreflang="uk" lang="uk" title="Наука про дані – Ukrainian"><span>Українська</span></a>
# https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BF%D1%80%D0%BE_%D0%B4%D0%B0%D0%BD%D1%96
#
# <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%DA%88%DB%8C%D9%B9%D8%A7_%D8%B3%D8%A7%D8%A6%D9%86%D8%B3" hreflang="ur" lang="ur" title="ڈیٹا سائنس – Urdu"><span>اردو</span></a>
# https://ur.wikipedia.org/wiki/%DA%88%DB%8C%D9%B9%D8%A7_%D8%B3%D8%A7%D8%A6%D9%86%D8%B3
#
# <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/Khoa_h%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u" hreflang="vi" lang="vi" title="Khoa học dữ liệu – Vietnamese"><span>Tiếng Việt</span></a>
# https://vi.wikipedia.org/wiki/Khoa_h%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u
#
# <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/%E6%95%B8%E6%93%9A%E7%A7%91%E5%AD%B8" hreflang="yue" lang="yue" title="數據科學 – Cantonese"><span>粵語</span></a>
# https://zh-yue.wikipedia.org/wiki/%E6%95%B8%E6%93%9A%E7%A7%91%E5%AD%B8
#
# <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6" hreflang="zh" lang="zh" title="数据科学 – Chinese"><span>中文</span></a>
# https://zh.wikipedia.org/wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6
#
# <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a>
# https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia
#
# <a accesskey="c" href="/wiki/Data_science" title="View the content page [c]"><span>Article</span></a>
# /wiki/Data_science
#
# <a accesskey="t" href="/wiki/Talk:Data_science" rel="discussion" title="Discuss improvements to the content page [t]"><span>Talk</span></a>
# /wiki/Talk:Data_science
#
# <a href="/wiki/Data_science"><span>Read</span></a>
# /wiki/Data_science
#
# <a accesskey="e" href="/w/index.php?title=Data_science&amp;action=edit" title="Edit this page [e]"><span>Edit</span></a>
# /w/index.php?title=Data_science&action=edit
#
# <a accesskey="h" href="/w/index.php?title=Data_science&amp;action=history" title="Past revisions of this page [h]"><span>View history</span></a>
# /w/index.php?title=Data_science&action=history
#
# <a href="/wiki/Data_science"><span>Read</span></a>
# /wiki/Data_science
#
# <a accesskey="e" href="/w/index.php?title=Data_science&amp;action=edit" title="Edit this page [e]"><span>Edit</span></a>
# /w/index.php?title=Data_science&action=edit
#
# <a href="/w/index.php?title=Data_science&amp;action=history"><span>View history</span></a>
# /w/index.php?title=Data_science&action=history
#
# <a accesskey="j" href="/wiki/Special:WhatLinksHere/Data_science" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a>
# /wiki/Special:WhatLinksHere/Data_science
#
# <a accesskey="k" href="/wiki/Special:RecentChangesLinked/Data_science" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a>
# /wiki/Special:RecentChangesLinked/Data_science
#
# <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a>
# /wiki/Wikipedia:File_Upload_Wizard
#
# <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a>
# /wiki/Special:SpecialPages
#
# <a href="/w/index.php?title=Data_science&amp;oldid=1218194882" title="Permanent link to this revision of this page"><span>Permanent link</span></a>
# /w/index.php?title=Data_science&oldid=1218194882
#
# <a href="/w/index.php?title=Data_science&amp;action=info" title="More information about this page"><span>Page information</span></a>
# /w/index.php?title=Data_science&action=info
#
# <a href="/w/index.php?title=Special:CiteThisPage&amp;page=Data_science&amp;id=1218194882&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a>
# /w/index.php?title=Special:CiteThisPage&page=Data_science&id=1218194882&wpFormIdentifier=titleform
#
# <a href="/w/index.php?title=Special:UrlShortener&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FData_science"><span>Get shortened URL</span></a>
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FData_science
#
# <a href="/w/index.php?title=Special:QrCode&amp;url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FData_science"><span>Download QR code</span></a>
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FData_science
#
# <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q2374463" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a>
# https://www.wikidata.org/wiki/Special:EntityPage/Q2374463
#
# <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Data_science&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a>
# /w/index.php?title=Special:DownloadAsPdf&page=Data_science&action=show-download-screen
#
# <a accesskey="p" href="/w/index.php?title=Data_science&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a>
# /w/index.php?title=Data_science&printable=yes
#
# <a href="https://commons.wikimedia.org/wiki/Category:Data_science" hreflang="en"><span>Wikimedia Commons</span></a>
# https://commons.wikimedia.org/wiki/Category:Data_science
#
# <a href="https://en.wikiversity.org/wiki/Data_science" hreflang="en"><span>Wikiversity</span></a>
# https://en.wikiversity.org/wiki/Data_science
#
# <a href="/wiki/Information_science" title="Information science">information science</a>
# /wiki/Information_science
#
# <a class="mw-file-description" href="/wiki/File:PIA23792-1600x1200(1).jpg"><img class="mw-file-element" data-file-height="1200" data-file-width="1600" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/220px-PIA23792-1600x1200%281%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/330px-PIA23792-1600x1200%281%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/440px-PIA23792-1600x1200%281%29.jpg 2x" width="220"/></a>
# /wiki/File:PIA23792-1600x1200(1).jpg
#
# <a href="/wiki/Comet_NEOWISE" title="Comet NEOWISE">Comet NEOWISE</a>
# /wiki/Comet_NEOWISE
#
# <a href="/wiki/Astronomical_survey" title="Astronomical survey">astronomical survey</a>
# /wiki/Astronomical_survey
#
# <a href="/wiki/Space_telescope" title="Space telescope">space telescope</a>
# /wiki/Space_telescope
#
# <a href="/wiki/Wide-field_Infrared_Survey_Explorer" title="Wide-field Infrared Survey Explorer">Wide-field Infrared Survey Explorer</a>
# /wiki/Wide-field_Infrared_Survey_Explorer
#
# <a class="mw-redirect" href="/wiki/Interdisciplinary" title="Interdisciplinary">interdisciplinary</a>
# /wiki/Interdisciplinary
#
# <a href="#cite_note-1">[1]</a>
# #cite_note-1
#
# <a href="/wiki/Statistics" title="Statistics">statistics</a>
# /wiki/Statistics
#
# <a class="mw-redirect" href="/wiki/Scientific_computing" title="Scientific computing">scientific computing</a>
# /wiki/Scientific_computing
#
# <a href="/wiki/Scientific_method" title="Scientific method">scientific methods</a>
# /wiki/Scientific_method
#
# <a href="/wiki/Algorithm" title="Algorithm">algorithms</a>
# /wiki/Algorithm
#
# <a href="/wiki/Knowledge" title="Knowledge">knowledge</a>
# /wiki/Knowledge
#
# <a href="/wiki/Unstructured_data" title="Unstructured data">unstructured data</a>
# /wiki/Unstructured_data
#
# <a href="#cite_note-2">[2]</a>
# #cite_note-2
#
# <a href="#cite_note-3">[3]</a>
# #cite_note-3
#
# <a href="#cite_note-4">[4]</a>
# #cite_note-4
#
# <a href="/wiki/Statistics" title="Statistics">statistics</a>
# /wiki/Statistics
#
# <a href="/wiki/Data_analysis" title="Data analysis">data analysis</a>
# /wiki/Data_analysis
#
# <a href="/wiki/Informatics" title="Informatics">informatics</a>
# /wiki/Informatics
#
# <a href="/wiki/Scientific_method" title="Scientific method">methods</a>
# /wiki/Scientific_method
#
# <a class="mw-redirect" href="/wiki/Phenomena" title="Phenomena">phenomena</a>
# /wiki/Phenomena
#
# <a href="/wiki/Data" title="Data">data</a>
# /wiki/Data
#
# <a href="#cite_note-5">[5]</a>
# #cite_note-5
#
# <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>
# /wiki/Mathematics
#
# <a href="/wiki/Computer_science" title="Computer science">computer science</a>
# /wiki/Computer_science
#
# <a href="/wiki/Information_science" title="Information science">information science</a>
# /wiki/Information_science
#
# <a href="/wiki/Domain_knowledge" title="Domain knowledge">domain knowledge</a>
# /wiki/Domain_knowledge
#
# <a href="#cite_note-:2-6">[6]</a>
# #cite_note-:2-6
#
# <a href="/wiki/Computer_science" title="Computer science">computer science</a>
# /wiki/Computer_science
#
# <a href="/wiki/Turing_Award" title="Turing Award">Turing Award</a>
# /wiki/Turing_Award
#
# <a href="/wiki/Jim_Gray_(computer_scientist)" title="Jim Gray (computer scientist)">Jim Gray</a>
# /wiki/Jim_Gray_(computer_scientist)
#
# <a href="/wiki/Empirical_research" title="Empirical research">empirical</a>
# /wiki/Empirical_research
#
# <a href="/wiki/Basic_research" title="Basic research">theoretical</a>
# /wiki/Basic_research
#
# <a href="/wiki/Computational_science" title="Computational science">computational</a>
# /wiki/Computational_science
#
# <a href="/wiki/Information_technology" title="Information technology">information technology</a>
# /wiki/Information_technology
#
# <a href="/wiki/Information_explosion" title="Information explosion">data deluge</a>
# /wiki/Information_explosion
#
# <a href="#cite_note-TansleyTolle2009-7">[7]</a>
# #cite_note-TansleyTolle2009-7
#
# <a href="#cite_note-BellHey2009-8">[8]</a>
# #cite_note-BellHey2009-8
#
# <a href="#cite_note-9">[9]</a>
# #cite_note-9
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=1" title="Edit section: Foundations"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=1
#
# <a href="/wiki/Interdisciplinarity" title="Interdisciplinarity">interdisciplinary</a>
# /wiki/Interdisciplinarity
#
# <a href="/wiki/Academic_discipline" title="Academic discipline">field</a>
# /wiki/Academic_discipline
#
# <a href="#cite_note-10">[10]</a>
# #cite_note-10
#
# <a href="/wiki/Knowledge_extraction" title="Knowledge extraction">extracting knowledge</a>
# /wiki/Knowledge_extraction
#
# <a href="/wiki/Big_data" title="Big data">large</a>
# /wiki/Big_data
#
# <a href="/wiki/Data_set" title="Data set">data sets</a>
# /wiki/Data_set
#
# <a class="mw-redirect" href="/wiki/Problem-solving" title="Problem-solving">solve problems</a>
# /wiki/Problem-solving
#
# <a href="/wiki/Analysis" title="Analysis">analyzing</a>
# /wiki/Analysis
#
# <a class="mw-redirect" href="/wiki/Data_visualization" title="Data visualization">data visualization</a>
# /wiki/Data_visualization
#
# <a class="mw-redirect" href="/wiki/Information_visualization" title="Information visualization">information visualization</a>
# /wiki/Information_visualization
#
# <a href="/wiki/Data_sonification" title="Data sonification">data sonification</a>
# /wiki/Data_sonification
#
# <a href="/wiki/Data_integration" title="Data integration">integration</a>
# /wiki/Data_integration
#
# <a href="/wiki/Graphic_design" title="Graphic design">graphic design</a>
# /wiki/Graphic_design
#
# <a class="mw-redirect" href="/wiki/Complex_systems" title="Complex systems">complex systems</a>
# /wiki/Complex_systems
#
# <a href="/wiki/Communication" title="Communication">communication</a>
# /wiki/Communication
#
# <a href="/wiki/Business" title="Business">business</a>
# /wiki/Business
#
# <a href="#cite_note-11">[11]</a>
# #cite_note-11
#
# <a href="#cite_note-12">[12]</a>
# #cite_note-12
#
# <a href="/wiki/Nathan_Yau" title="Nathan Yau">Nathan Yau</a>
# /wiki/Nathan_Yau
#
# <a href="/wiki/Ben_Fry" title="Ben Fry">Ben Fry</a>
# /wiki/Ben_Fry
#
# <a href="/wiki/Human%E2%80%93computer_interaction" title="Human–computer interaction">human–computer interaction</a>
# /wiki/Human%E2%80%93computer_interaction
#
# <a href="/wiki/Exploration" title="Exploration">explore</a>
# /wiki/Exploration
#
# <a href="#cite_note-13">[13]</a>
# #cite_note-13
#
# <a href="#cite_note-14">[14]</a>
# #cite_note-14
#
# <a href="/wiki/American_Statistical_Association" title="American Statistical Association">American Statistical Association</a>
# /wiki/American_Statistical_Association
#
# <a href="/wiki/Database" title="Database">database</a>
# /wiki/Database
#
# <a href="/wiki/Machine_learning" title="Machine learning">machine learning</a>
# /wiki/Machine_learning
#
# <a href="/wiki/Distributed_computing" title="Distributed computing">distributed and parallel systems</a>
# /wiki/Distributed_computing
#
# <a href="#cite_note-15">[15]</a>
# #cite_note-15
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=2" title="Edit section: Relationship to statistics"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=2
#
# <a href="/wiki/Nate_Silver" title="Nate Silver">Nate Silver</a>
# /wiki/Nate_Silver
#
# <a href="#cite_note-16">[16]</a>
# #cite_note-16
#
# <a href="#cite_note-17">[17]</a>
# #cite_note-17
#
# <a href="/wiki/Vasant_Dhar" title="Vasant Dhar">Vasant Dhar</a>
# /wiki/Vasant_Dhar
#
# <a href="#cite_note-18">[18]</a>
# #cite_note-18
#
# <a href="/wiki/Andrew_Gelman" title="Andrew Gelman">Andrew Gelman</a>
# /wiki/Andrew_Gelman
#
# <a href="/wiki/Columbia_University" title="Columbia University">Columbia University</a>
# /wiki/Columbia_University
#
# <a href="#cite_note-19">[19]</a>
# #cite_note-19
#
# <a href="/wiki/David_Donoho" title="David Donoho">David Donoho</a>
# /wiki/David_Donoho
#
# <a href="#cite_note-:7-20">[20]</a>
# #cite_note-:7-20
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=3" title="Edit section: Etymology"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=3
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=4" title="Edit section: Early usage"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=4
#
# <a href="/wiki/John_Tukey" title="John Tukey">John Tukey</a>
# /wiki/John_Tukey
#
# <a href="#cite_note-:7-20">[20]</a>
# #cite_note-:7-20
#
# <a href="/wiki/C._F._Jeff_Wu" title="C. F. Jeff Wu">C. F. Jeff Wu</a>
# /wiki/C._F._Jeff_Wu
#
# <a href="#cite_note-21">[21]</a>
# #cite_note-21
#
# <a href="/wiki/Montpellier_2_University" title="Montpellier 2 University">University of Montpellier  II</a>
# /wiki/Montpellier_2_University
#
# <a href="#cite_note-22">[22]</a>
# #cite_note-22
#
# <a href="#cite_note-Murtagh_2018_14-23">[23]</a>
# #cite_note-Murtagh_2018_14-23
#
# <a href="/wiki/Peter_Naur" title="Peter Naur">Peter Naur</a>
# /wiki/Peter_Naur
#
# <a href="#cite_note-:2-6">[6]</a>
# #cite_note-:2-6
#
# <a href="#cite_note-:2-6">[6]</a>
# #cite_note-:2-6
#
# <a href="/wiki/C._F._Jeff_Wu" title="C. F. Jeff Wu">C. F. Jeff Wu</a>
# /wiki/C._F._Jeff_Wu
#
# <a href="#cite_note-24">[24]</a>
# #cite_note-24
#
# <a href="#cite_note-Murtagh_2018_14-23">[23]</a>
# #cite_note-Murtagh_2018_14-23
#
# <a href="/wiki/Data_mining" title="Data mining">data mining</a>
# /wiki/Data_mining
#
# <a href="#cite_note-:2-6">[6]</a>
# #cite_note-:2-6
#
# <a href="#cite_note-:1-25">[25]</a>
# #cite_note-:1-25
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=5" title="Edit section: Modern usage"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=5
#
# <a href="/wiki/Thomas_H._Davenport" title="Thomas H. Davenport">Thomas H. Davenport</a>
# /wiki/Thomas_H._Davenport
#
# <a href="/wiki/DJ_Patil" title="DJ Patil">DJ Patil</a>
# /wiki/DJ_Patil
#
# <a href="#cite_note-26">[26]</a>
# #cite_note-26
#
# <a class="mw-redirect" href="/wiki/New_York_Times" title="New York Times">New York Times</a>
# /wiki/New_York_Times
#
# <a href="#cite_note-27">[27]</a>
# #cite_note-27
#
# <a class="mw-redirect" href="/wiki/Boston_Globe" title="Boston Globe">Boston Globe</a>
# /wiki/Boston_Globe
#
# <a href="#cite_note-28">[28]</a>
# #cite_note-28
#
# <a href="#cite_note-29">[29]</a>
# #cite_note-29
#
# <a href="/wiki/William_S._Cleveland" title="William S. Cleveland">William S. Cleveland</a>
# /wiki/William_S._Cleveland
#
# <a href="#cite_note-30">[30]</a>
# #cite_note-30
#
# <a href="#cite_note-:1-25">[25]</a>
# #cite_note-:1-25
#
# <a class="mw-redirect" href="/wiki/Committee_on_Data_for_Science_and_Technology" title="Committee on Data for Science and Technology">Committee on Data for Science and Technology</a>
# /wiki/Committee_on_Data_for_Science_and_Technology
#
# <a href="#cite_note-:1-25">[25]</a>
# #cite_note-:1-25
#
# <a href="/wiki/American_Statistical_Association" title="American Statistical Association">American Statistical Association</a>
# /wiki/American_Statistical_Association
#
# <a href="#cite_note-31">[31]</a>
# #cite_note-31
#
# <a href="/wiki/DJ_Patil" title="DJ Patil">DJ Patil</a>
# /wiki/DJ_Patil
#
# <a href="/wiki/Jeff_Hammerbacher" title="Jeff Hammerbacher">Jeff Hammerbacher</a>
# /wiki/Jeff_Hammerbacher
#
# <a href="#cite_note-32">[32]</a>
# #cite_note-32
#
# <a href="/wiki/National_Science_Board" title="National Science Board">National Science Board</a>
# /wiki/National_Science_Board
#
# <a href="/wiki/Data_collection" title="Data collection">data collection</a>
# /wiki/Data_collection
#
# <a href="#cite_note-33">[33]</a>
# #cite_note-33
#
# <a href="/wiki/Buzzword" title="Buzzword">buzzword</a>
# /wiki/Buzzword
#
# <a href="#cite_note-34">[34]</a>
# #cite_note-34
#
# <a href="/wiki/Big_data" title="Big data">Big data</a>
# /wiki/Big_data
#
# <a href="#cite_note-:5-35">[35]</a>
# #cite_note-:5-35
#
# <a href="#cite_note-:6-36">[36]</a>
# #cite_note-:6-36
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=6" title="Edit section: Data science and data analysis"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=6
#
# <a class="mw-file-description" href="/wiki/File:EDA_example_-_Always_plot_your_data.jpg"><img alt="summary statistics and scatterplots showing the Datasaurus dozen data set" class="mw-file-element" data-file-height="986" data-file-width="929" decoding="async" height="233" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/29/EDA_example_-_Always_plot_your_data.jpg/220px-EDA_example_-_Always_plot_your_data.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/29/EDA_example_-_Always_plot_your_data.jpg/330px-EDA_example_-_Always_plot_your_data.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/29/EDA_example_-_Always_plot_your_data.jpg/440px-EDA_example_-_Always_plot_your_data.jpg 2x" width="220"/></a>
# /wiki/File:EDA_example_-_Always_plot_your_data.jpg
#
# <a href="/wiki/Exploratory_data_analysis" title="Exploratory data analysis">exploratory data analysis</a>
# /wiki/Exploratory_data_analysis
#
# <a href="/wiki/Datasaurus_dozen" title="Datasaurus dozen">Datasaurus dozen</a>
# /wiki/Datasaurus_dozen
#
# <a href="/wiki/Data_management" title="Data management">data management</a>
# /wiki/Data_management
#
# <a class="mw-redirect" href="/wiki/Interdisciplinary_field" title="Interdisciplinary field">interdisciplinary field</a>
# /wiki/Interdisciplinary_field
#
# <a href="/wiki/Machine_learning" title="Machine learning">machine learning</a>
# /wiki/Machine_learning
#
# <a href="#cite_note-:8-37">[37]</a>
# #cite_note-:8-37
#
# <a href="#cite_note-:9-38">[38]</a>
# #cite_note-:9-38
#
# <a class="mw-redirect" href="/wiki/Data_cleaning" title="Data cleaning">data cleaning</a>
# /wiki/Data_cleaning
#
# <a class="mw-redirect" href="/wiki/Data_visualization" title="Data visualization">data visualization</a>
# /wiki/Data_visualization
#
# <a class="mw-redirect" href="/wiki/Variable_(research)" title="Variable (research)">variables</a>
# /wiki/Variable_(research)
#
# <a class="mw-redirect" href="/wiki/Data_analyst" title="Data analyst">data analyst</a>
# /wiki/Data_analyst
#
# <a href="#cite_note-:8-37">[37]</a>
# #cite_note-:8-37
#
# <a class="mw-redirect" href="/wiki/Iterative" title="Iterative">iterative</a>
# /wiki/Iterative
#
# <a href="/wiki/Unstructured_data" title="Unstructured data">unstructured data</a>
# /wiki/Unstructured_data
#
# <a href="/wiki/Machine_learning" title="Machine learning">machine learning</a>
# /wiki/Machine_learning
#
# <a class="mw-redirect" href="/wiki/Statistical_analysis" title="Statistical analysis">statistical analysis</a>
# /wiki/Statistical_analysis
#
# <a href="/wiki/Data_preprocessing" title="Data preprocessing">data preprocessing</a>
# /wiki/Data_preprocessing
#
# <a href="/wiki/Feature_engineering" title="Feature engineering">feature engineering</a>
# /wiki/Feature_engineering
#
# <a class="mw-redirect" href="/wiki/Machine_learning_algorithms" title="Machine learning algorithms">machine learning algorithms</a>
# /wiki/Machine_learning_algorithms
#
# <a href="#cite_note-:9-38">[38]</a>
# #cite_note-:9-38
#
# <a href="#cite_note-:10-39">[39]</a>
# #cite_note-:10-39
#
# <a href="/wiki/Computer_science" title="Computer science">computer science</a>
# /wiki/Computer_science
#
# <a class="mw-redirect" href="/wiki/Domain_expertise" title="Domain expertise">domain expertise</a>
# /wiki/Domain_expertise
#
# <a href="#cite_note-:9-38">[38]</a>
# #cite_note-:9-38
#
# <a href="/wiki/Computer_programming" title="Computer programming">programming</a>
# /wiki/Computer_programming
#
# <a class="mw-redirect" href="/wiki/Data_visualization" title="Data visualization">data visualization</a>
# /wiki/Data_visualization
#
# <a href="/wiki/Critical_thinking" title="Critical thinking">critical thinking</a>
# /wiki/Critical_thinking
#
# <a href="/wiki/Domain_knowledge" title="Domain knowledge">domain knowledge</a>
# /wiki/Domain_knowledge
#
# <a href="#cite_note-:8-37">[37]</a>
# #cite_note-:8-37
#
# <a href="#cite_note-:9-38">[38]</a>
# #cite_note-:9-38
#
# <a href="/wiki/Data_management" title="Data management">data management</a>
# /wiki/Data_management
#
# <a class="mw-redirect" href="/wiki/Structured_data" title="Structured data">structured data</a>
# /wiki/Structured_data
#
# <a class="mw-redirect" href="/wiki/Statistical_analysis" title="Statistical analysis">statistical analysis</a>
# /wiki/Statistical_analysis
#
# <a href="/wiki/Machine_learning" title="Machine learning">machine learning</a>
# /wiki/Machine_learning
#
# <a href="/wiki/Decision-making" title="Decision-making">decision-making</a>
# /wiki/Decision-making
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=7" title="Edit section: History"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=7
#
# <a class="mw-file-description" href="/wiki/File:Wiki_letter_w_cropped.svg"><img alt="[icon]" class="mw-file-element" data-file-height="31" data-file-width="44" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/20px-Wiki_letter_w_cropped.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/30px-Wiki_letter_w_cropped.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/40px-Wiki_letter_w_cropped.svg.png 2x" width="20"/></a>
# /wiki/File:Wiki_letter_w_cropped.svg
#
# <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Data_science&amp;action=edit&amp;section=">adding to it</a>
# https://en.wikipedia.org/w/index.php?title=Data_science&action=edit&section=
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=8" title="Edit section: See also"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=8
#
# <a href="/wiki/ODSC" title="ODSC">Open Data Science Conference</a>
# /wiki/ODSC
#
# <a href="/wiki/Scientific_Data_(journal)" title="Scientific Data (journal)">Scientific Data</a>
# /wiki/Scientific_Data_(journal)
#
# <a href="/wiki/Women_in_Data" title="Women in Data">Women in Data</a>
# /wiki/Women_in_Data
#
# <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python (programming language)</a>
# /wiki/Python_(programming_language)
#
# <a href="/wiki/R_(programming_language)" title="R (programming language)">R (programming language)</a>
# /wiki/R_(programming_language)
#
# <a href="/wiki/Data_engineering" title="Data engineering">Data engineering</a>
# /wiki/Data_engineering
#
# <a href="/wiki/Big_data" title="Big data">Big data</a>
# /wiki/Big_data
#
# <a href="/wiki/Machine_learning" title="Machine learning">Machine learning</a>
# /wiki/Machine_learning
#
# <a href="/w/index.php?title=Data_science&amp;action=edit&amp;section=9" title="Edit section: References"><span>edit</span></a>
# /w/index.php?title=Data_science&action=edit&section=9
#
# <a href="#cite_ref-1">^</a>
# #cite_ref-1
#
# <a class="external text" href="https://doi.org/10.1080%2F10618600.2017.1384734" rel="nofollow">"50 Years of Data Science"</a>
# https://doi.org/10.1080%2F10618600.2017.1384734
#
# <a href="/wiki/Journal_of_Computational_and_Graphical_Statistics" title="Journal of Computational and Graphical Statistics">Journal of Computational and Graphical Statistics</a>
# /wiki/Journal_of_Computational_and_Graphical_Statistics
#
# <a class="mw-redirect" href="/wiki/Doi_(identifier)" title="Doi (identifier)">doi</a>
# /wiki/Doi_(identifier)
#
# <a class="external text" href="https://doi.org/10.1080%2F10618600.2017.1384734" rel="nofollow">10.1080/10618600.2017.1384734</a>
# https://doi.org/10.1080%2F10618600.2017.1384734
#
# <a class="mw-redirect" href="/wiki/S2CID_(identifier)" title="S2CID (identifier)">S2CID</a>
# /wiki/S2CID_(identifier)
#
# <a class="external text" href="https://api.semanticscholar.org/CorpusID:114558008" rel="nofollow">114558008</a>
# https://api.semanticscholar.org/CorpusID:114558008
#
# <a href="#cite_ref-2">^</a>
# #cite_ref-2
#
# <a class="external text" href="http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext" rel="nofollow">"Data science and prediction"</a>
# http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext
#
# <a class="mw-redirect" href="/wiki/Doi_(identifier)" title="Doi (identifier)">doi</a>
# /wiki/Doi_(identifier)
#
# <a class="external text" href="https://doi.org/10.1145%2F2500499" rel="nofollow">10.1145/2500499</a>
# https://doi.org/10.1145%2F2500499
#
# <a class="mw-redirect" href="/wiki/S2CID_(identifier)" title="S2CID (identifier)">S2CID</a>
# /wiki/S2CID_(identifier)
#
# <a class="external text" href="https://api.semanticscholar.org/CorpusID:6107147" rel="nofollow">6107147</a>
# https://api.semanticscholar.org/CorpusID:6107147
#
# <a class="external text" href="https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext" rel="nofollow">Archived</a>
# https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext
#
# <a href="#cite_ref-3">^</a>
# #cite_ref-3
#
# <a class="external text" href="https://dstf.acm.org/DSTF_Final_Report.pdf" rel="nofollow">Computing Competencies for Undergraduate Data Science Curricula</a>
# https://dstf.acm.org/DSTF_Final_Report.pdf
#
# <a href="#cite_ref-4">^</a>
# #cite_ref-4
#
# <a class="external text" href="https://doi.org/10.1145%2F3575663" rel="nofollow">"What is Data Science?"</a>
# https://doi.org/10.1145%2F3575663
#
# <a class="mw-redirect" href="/wiki/Doi_(identifier)" title="Doi (identifier)">doi</a>
# /wiki/Doi_(identifier)
#
# <a class="external text" href="https://doi.org/10.1145%2F3575663" rel="nofollow">10.1145/3575663</a>
# https://doi.org/10.1145%2F3575663
#
# <a class="mw-redirect" href="/wiki/ISSN_(identifier)" title="ISSN (identifier)">ISSN</a>
# /wiki/ISSN_(identifier)
#
# <a class="external text" href="https://www.worldcat.org/issn/0001-0782" rel="nofollow">0001-0782</a>
# https://www.worldcat.org/issn/0001-0782
#
# <a href="#cite_ref-5">^</a>
# #cite_ref-5
#
# <a class="external text" href="https://www.springer.com/book/9784431702085" rel="nofollow">"What is Data Science ? Fundamental Concepts and a Heuristic Example"</a>
# https://www.springer.com/book/9784431702085
#
# <a class="mw-redirect" href="/wiki/Doi_(identifier)" title="Doi (identifier)">doi</a>
# /wiki/Doi_(identifier)
#
# <a class="external text" href="https://doi.org/10.1007%2F978-4-431-65950-1_3" rel="nofollow">10.1007/978-4-431-65950-1_3</a>
# https://doi.org/10.1007%2F978-4-431-65950-1_3
#
# <a class="mw-redirect" href="/wiki/ISBN_(identifier)" title="ISBN (identifier)">ISBN</a>
# /wiki/ISBN_(identifier)
#
# <a href="/wiki/Special:BookSources/9784431702085" title="Special:BookSources/9784431702085"><bdi>9784431702085</bdi></a>
# /wiki/Special:BookSources/9784431702085
#
# <a href="#cite_ref-:2_6-0"><sup><i><b>a</b></i></sup></a>
# #cite_ref-:2_6-0
#
# <a href="#cite_ref-:2_6-1"><sup><i><b>b</b></i></sup></a>
# #cite_ref-:2_6-1
#
# <a href="#cite_ref-:2_6-2"><sup><i><b>c</b></i></sup></a>
# #cite_ref-:2_6-2
#
# <a href="#cite_ref-:2_6-3"><sup><i><b>d</b></i></sup></a>
# #cite_ref-:2_6-3
#
# <a class="external text" href="https://doi.org/10.1145%2F3076253" rel="nofollow">"Data Science: A Comprehensive Overview"</a>
# https://doi.org/10.1145%2F3076253
#
# <a class="mw-redirect" href="/wiki/ArXiv_(identifier)" title="ArXiv (identifier)">arXiv</a>
# /wiki/ArXiv_(identifier)
#
# <a class="external text" href="https://arxiv.org/abs/2007.03606" rel="nofollow">2007.03606</a>
# https://arxiv.org/abs/2007.03606
#
# <a class="mw-redirect" href="/wiki/Doi_(identifier)" title="Doi (identifier)">doi</a>
# /wiki/Doi_(identifier)
#
# <a class="external text" href="https://doi.org/10.1145%2F3076253" rel="nofollow">10.1145/3076253</a>
# https://doi.org/10.1145%2F3076253
#
# <a class="mw-redirect" href="/wiki/ISSN_(identifier)" title="ISSN (identifier)">ISSN</a>
# /wiki/ISSN_(identifier)
#
# ...
# /wiki/New_York_Times
#
# <a href="/wiki/New_York_City" title="New York City">New York City</a>
# /wiki/New_York_City
#
# <a href="#cite_ref-28">^</a>
# #cite_ref-28
#
# <a class="external text" href="https://www.bostonglobe.com/business/2015/11/11/behind-scenes-sexiest-job-century/Kc1cvXIu31DfHhVmyRQeIJ/story.html" rel="nofollow">"Behind the scenes of the 'sexiest job of the 21st century'<span class="cs1-kern-right"></span>"</a>
# https://www.bostonglobe.com/business/2015/11/11/behind-scenes-sexiest-job-century/Kc1cvXIu31DfHhVmyRQeIJ/story.html
#
# <a class="mw-redirect" href="/wiki/Boston_Globe" title="Boston Globe">Boston Globe</a>
# /wiki/Boston_Globe
#
# <a href="/wiki/Boston" title="Boston">Boston</a>
# /wiki/Boston
#
# <a href="#cite_ref-29">^</a>
# #cite_ref-29
#
# <a class="external text" href="https://hbr.org/2022/07/is-data-scientist-still-the-sexiest-job-of-the-21st-century" rel="nofollow">"Is Data Scientist Still the Sexiest Job of the 21st Century?"</a>
# https://hbr.org/2022/07/is-data-scientist-still-the-sexiest-job-of-the-21st-century
#
# <a href="/wiki/Harvard_Business_Review" title="Harvard Business Review">Harvard Business Review</a>
# /wiki/Harvard_Business_Review
#
# <a href="#cite_ref-30">^</a>
# #cite_ref-30
#
# <a class="external text" href="https://www.stat.purdue.edu/~wsc/" rel="nofollow">"William S. Cleveland"</a>
# https://www.stat.purdue.edu/~wsc/
#
# <a href="#cite_ref-31">^</a>
# #cite_ref-31
#
# <a class="external text" href="https://magazine.amstat.org/blog/2016/06/01/datascience-2/" rel="nofollow">"ASA Expands Scope, Outreach to Foster Growth, Collaboration in Data Science"</a>
# https://magazine.amstat.org/blog/2016/06/01/datascience-2/
#
# <a href="/wiki/American_Statistical_Association" title="American Statistical Association">American Statistical Association</a>
# /wiki/American_Statistical_Association
#
# <a href="#cite_ref-32">^</a>
# #cite_ref-32
#
# <a class="external text" href="https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century" rel="nofollow">"Data Scientist: The Sexiest Job of the 21st Century"</a>
# https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century
#
# <a class="mw-redirect" href="/wiki/ISSN_(identifier)" title="ISSN (identifier)">ISSN</a>
# /wiki/ISSN_(identifier)
#
# <a class="external text" href="https://www.worldcat.org/issn/0017-8012" rel="nofollow">0017-8012</a>
# https://www.worldcat.org/issn/0017-8012
#
# <a href="#cite_ref-33">^</a>
# #cite_ref-33
#
# <a class="external text" href="https://www.nsf.gov/pubs/2005/nsb0540/" rel="nofollow">"US NSF – NSB-05-40, Long-Lived Digital Data Collections Enabling Research and Education in the 21st Century"</a>
# https://www.nsf.gov/pubs/2005/nsb0540/
#
# <a href="#cite_ref-34">^</a>
# #cite_ref-34
#
# <a class="external text" href="https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/" rel="nofollow">"Data Science: What's The Half-Life of a Buzzword?"</a>
# https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/
#
# <a href="/wiki/Forbes" title="Forbes">Forbes</a>
# /wiki/Forbes
#
# <a href="#cite_ref-:5_35-0">^</a>
# #cite_ref-:5_35-0
#
# <a class="external text" href="https://www.forbes.com/sites/peterpham/2015/08/28/the-impacts-of-big-data-that-you-may-not-have-heard-of/" rel="nofollow">"The Impacts of Big Data That You May Not Have Heard Of"</a>
# https://www.forbes.com/sites/peterpham/2015/08/28/the-impacts-of-big-data-that-you-may-not-have-heard-of/
#
# <a href="#cite_ref-:6_36-0">^</a>
# #cite_ref-:6_36-0
#
# <a class="external text" href="https://static1.squarespace.com/static/5ff2adbe3fe4fe33db902812/t/6009dd9fa7bc363aa822d2c7/1611259312432/ISLR+Seventh+Printing.pdf" rel="nofollow">"How Data Science will Impact Future of Businesses?"</a>
# https://static1.squarespace.com/static/5ff2adbe3fe4fe33db902812/t/6009dd9fa7bc363aa822d2c7/1611259312432/ISLR+Seventh+Printing.pdf
#
# <a href="#cite_ref-:8_37-0"><sup><i><b>a</b></i></sup></a>
# #cite_ref-:8_37-0
#
# <a href="#cite_ref-:8_37-1"><sup><i><b>b</b></i></sup></a>
# #cite_ref-:8_37-1
#
# <a href="#cite_ref-:8_37-2"><sup><i><b>c</b></i></sup></a>
# #cite_ref-:8_37-2
#
# <a class="external text" href="https://www.researchgate.net/publication/354866394" rel="nofollow">"An Introduction to Statistical Learning: with Applications in R."</a>
# https://www.researchgate.net/publication/354866394
#
# <a href="#cite_ref-:9_38-0"><sup><i><b>a</b></i></sup></a>
# #cite_ref-:9_38-0
#
# <a href="#cite_ref-:9_38-1"><sup><i><b>b</b></i></sup></a>
# #cite_ref-:9_38-1
#
# <a href="#cite_ref-:9_38-2"><sup><i><b>c</b></i></sup></a>
# #cite_ref-:9_38-2
#
# <a href="#cite_ref-:9_38-3"><sup><i><b>d</b></i></sup></a>
# #cite_ref-:9_38-3
#
# <a class="external text" href="https://www.researchgate.net/publication/256438799" rel="nofollow">"Data Science for Business: What You Need to Know about Data Mining and Data-Analytic Thinking"</a>
# https://www.researchgate.net/publication/256438799
#
# <a href="#cite_ref-:10_39-0">^</a>
# #cite_ref-:10_39-0
#
# <a class="external text" href="https://www.sciencedirect.com/book/9780123814791/data-mining-concepts-and-techniques" rel="nofollow"><i>Data Mining: Concepts and Techniques</i></a>
# https://www.sciencedirect.com/book/9780123814791/data-mining-concepts-and-techniques
#
# <a class="mw-redirect" href="/wiki/ISBN_(identifier)" title="ISBN (identifier)">ISBN</a>
# /wiki/ISBN_(identifier)
#
# <a href="/wiki/Special:BookSources/9780123814791" title="Special:BookSources/9780123814791"><bdi>9780123814791</bdi></a>
# /wiki/Special:BookSources/9780123814791
#
# <a href="/wiki/Template:Data" title="Template:Data"><abbr style=";;background:none transparent;border:none;box-shadow:none;padding:0;" title="View this template">v</abbr></a>
# /wiki/Template:Data
#
# <a href="/wiki/Template_talk:Data" title="Template talk:Data"><abbr style=";;background:none transparent;border:none;box-shadow:none;padding:0;" title="Discuss this template">t</abbr></a>
# /wiki/Template_talk:Data
#
# <a href="/wiki/Special:EditPage/Template:Data" title="Special:EditPage/Template:Data"><abbr style=";;background:none transparent;border:none;box-shadow:none;padding:0;" title="Edit this template">e</abbr></a>
# /wiki/Special:EditPage/Template:Data
#
# <a href="/wiki/Data_(computer_science)" title="Data (computer science)">Data</a>
# /wiki/Data_(computer_science)
#
# <a href="/wiki/Data_acquisition" title="Data acquisition">Acquisition</a>
# /wiki/Data_acquisition
#
# <a href="/wiki/Data_augmentation" title="Data augmentation">Augmentation</a>
# /wiki/Data_augmentation
#
# <a href="/wiki/Data_analysis" title="Data analysis">Analysis</a>
# /wiki/Data_analysis
#
# <a href="/wiki/Data_archaeology" title="Data archaeology">Archaeology</a>
# /wiki/Data_archaeology
#
# <a href="/wiki/Big_data" title="Big data">Big</a>
# /wiki/Big_data
#
# <a href="/wiki/Data_cleansing" title="Data cleansing">Cleansing</a>
# /wiki/Data_cleansing
#
# <a href="/wiki/Data_collection" title="Data collection">Collection</a>
# /wiki/Data_collection
#
# <a href="/wiki/Data_compression" title="Data compression">Compression</a>
# /wiki/Data_compression
#
# <a href="/wiki/Data_corruption" title="Data corruption">Corruption</a>
# /wiki/Data_corruption
#
# <a href="/wiki/Data_curation" title="Data curation">Curation</a>
# /wiki/Data_curation
#
# <a href="/wiki/Data_degradation" title="Data degradation">Degradation</a>
# /wiki/Data_degradation
#
# <a href="/wiki/Data_editing" title="Data editing">Editing</a>
# /wiki/Data_editing
#
# <a href="/wiki/Extract,_transform,_load" title="Extract, transform, load">ETL</a>
# /wiki/Extract,_transform,_load
#
# <a href="/wiki/Extract,_load,_transform" title="Extract, load, transform">ELT</a>
# /wiki/Extract,_load,_transform
#
# <a href="/wiki/Data_extraction" title="Data extraction">Extract</a>
# /wiki/Data_extraction
#
# <a class="mw-redirect" href="/wiki/Data_transformation" title="Data transformation">Transform</a>
# /wiki/Data_transformation
#
# <a href="/wiki/Data_loading" title="Data loading">Load</a>
# /wiki/Data_loading
#
# <a href="/wiki/Data_farming" title="Data farming">Farming</a>
# /wiki/Data_farming
#
# <a href="/wiki/Data_format_management" title="Data format management">Format management</a>
# /wiki/Data_format_management
#
# <a href="/wiki/Data_fusion" title="Data fusion">Fusion</a>
# /wiki/Data_fusion
#
# <a href="/wiki/Data_integration" title="Data integration">Integration</a>
# /wiki/Data_integration
#
# <a href="/wiki/Data_integrity" title="Data integrity">Integrity</a>
# /wiki/Data_integrity
#
# <a class="mw-redirect" href="/wiki/Data_library" title="Data library">Library</a>
# /wiki/Data_library
#
# <a href="/wiki/Data_lineage" title="Data lineage">Lineage</a>
# /wiki/Data_lineage
#
# <a href="/wiki/Data_loss" title="Data loss">Loss</a>
# /wiki/Data_loss
#
# <a href="/wiki/Data_management" title="Data management">Management</a>
# /wiki/Data_management
#
# <a href="/wiki/Data_migration" title="Data migration">Migration</a>
# /wiki/Data_migration
#
# <a href="/wiki/Data_mining" title="Data mining">Mining</a>
# /wiki/Data_mining
#
# <a href="/wiki/Data_philanthropy" title="Data philanthropy">Philanthropy</a>
# /wiki/Data_philanthropy
#
# <a class="mw-redirect" href="/wiki/Data_pre-processing" title="Data pre-processing">Pre-processing</a>
# /wiki/Data_pre-processing
#
# <a href="/wiki/Data_preservation" title="Data preservation">Preservation</a>
# /wiki/Data_preservation
#
# <a href="/wiki/Data_processing" title="Data processing">Processing</a>
# /wiki/Data_processing
#
# <a href="/wiki/Information_privacy" title="Information privacy">Protection (privacy)</a>
# /wiki/Information_privacy
#
# <a href="/wiki/Data_publishing" title="Data publishing">Publishing</a>
# /wiki/Data_publishing
#
# <a href="/wiki/Data_recovery" title="Data recovery">Recovery</a>
# /wiki/Data_recovery
#
# <a href="/wiki/Data_reduction" title="Data reduction">Reduction</a>
# /wiki/Data_reduction
#
# <a href="/wiki/Data_retention" title="Data retention">Retention</a>
# /wiki/Data_retention
#
# <a href="/wiki/Data_quality" title="Data quality">Quality</a>
# /wiki/Data_quality
#
# <a class="mw-selflink selflink">Science</a>
#
# <a href="/wiki/Data_scraping" title="Data scraping">Scraping</a>
# /wiki/Data_scraping
#
# <a href="/wiki/Data_scrubbing" title="Data scrubbing">Scrubbing</a>
# /wiki/Data_scrubbing
#
# <a href="/wiki/Data_security" title="Data security">Security</a>
# /wiki/Data_security
#
# <a href="/wiki/Data_steward" title="Data steward">Stewardship</a>
# /wiki/Data_steward
#
# <a href="/wiki/Data_storage" title="Data storage">Storage</a>
# /wiki/Data_storage
#
# <a href="/wiki/Data_synchronization" title="Data synchronization">Synchronization</a>
# /wiki/Data_synchronization
#
# <a href="/wiki/Data_validation" title="Data validation">Validation</a>
# /wiki/Data_validation
#
# <a href="/wiki/Data_warehouse" title="Data warehouse">Warehouse</a>
# /wiki/Data_warehouse
#
# <a href="/wiki/Data_wrangling" title="Data wrangling">Wrangling/munging</a>
# /wiki/Data_wrangling
#
# <a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Data_science&amp;oldid=1218194882">https://en.wikipedia.org/w/index.php?title=Data_science&amp;oldid=1218194882</a>
# https://en.wikipedia.org/w/index.php?title=Data_science&oldid=1218194882
#
# <a href="/wiki/Help:Category" title="Help:Category">Categories</a>
# /wiki/Help:Category
#
# <a href="/wiki/Category:Information_science" title="Category:Information science">Information science</a>
# /wiki/Category:Information_science
#
# <a href="/wiki/Category:Computer_occupations" title="Category:Computer occupations">Computer occupations</a>
# /wiki/Category:Computer_occupations
#
# <a href="/wiki/Category:Computational_fields_of_study" title="Category:Computational fields of study">Computational fields of study</a>
# /wiki/Category:Computational_fields_of_study
#
# <a href="/wiki/Category:Data_analysis" title="Category:Data analysis">Data analysis</a>
# /wiki/Category:Data_analysis
#
# <a href="/wiki/Category:Data_science" title="Category:Data science">Data science</a>
# /wiki/Category:Data_science
#
# <a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">Articles with short description</a>
# /wiki/Category:Articles_with_short_description
#
# <a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">Short description is different from Wikidata</a>
# /wiki/Category:Short_description_is_different_from_Wikidata
#
# <a href="/wiki/Category:Use_dmy_dates_from_August_2023" title="Category:Use dmy dates from August 2023">Use dmy dates from August 2023</a>
# /wiki/Category:Use_dmy_dates_from_August_2023
#
# <a href="/wiki/Category:Articles_to_be_expanded_from_August_2023" title="Category:Articles to be expanded from August 2023">Articles to be expanded from August 2023</a>
# /wiki/Category:Articles_to_be_expanded_from_August_2023
#
# <a href="/wiki/Category:All_articles_to_be_expanded" title="Category:All articles to be expanded">All articles to be expanded</a>
# /wiki/Category:All_articles_to_be_expanded
#
# <a href="/wiki/Category:Articles_using_small_message_boxes" title="Category:Articles using small message boxes">Articles using small message boxes</a>
# /wiki/Category:Articles_using_small_message_boxes
#
# <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license">Creative Commons Attribution-ShareAlike License 4.0</a>
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
#
# <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license" style="display:none;"></a>
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
#
# <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use">Terms of Use</a>
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
#
# <a href="//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy Policy</a>
# //foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
#
# <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>
# //www.wikimediafoundation.org/
#
# <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy policy</a>
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
#
# <a href="/wiki/Wikipedia:About">About Wikipedia</a>
# /wiki/Wikipedia:About
#
# <a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a>
# /wiki/Wikipedia:General_disclaimer
#
# <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a>
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
#
# <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">Code of Conduct</a>
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
#
# <a href="https://developer.wikimedia.org">Developers</a>
# https://developer.wikimedia.org
#
# <a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a>
# https://stats.wikimedia.org/#/en.wikipedia.org
#
# <a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">Cookie statement</a>
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
#
# <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Data_science&amp;mobileaction=toggle_view_mobile">Mobile view</a>
# //en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile
#
# <a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a>
# https://wikimediafoundation.org/
#
# <a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a>
# https://www.mediawiki.org/

# %% [markdown]
# ### Filter Links
# There is a certain type of web link that links to another wikipedia page about some keyword.
#
# For example, the hyperlink \<a href="/wiki/Data_analysis" title="Data analysis">data analysis</a> points to another wikipedia page about data analysis.
#
# Therefore, we can use the pattern "/wiki/{keyword}" to filter links within a wiki page.

# %%
# Send a GET request to a URL
response = requests.get("https://en.wikipedia.org/wiki/Data_science")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print all links on the web page
    links = soup.find_all('a', href=True) # href=True requires a link should have href attribute
    for link in links:
        if link['href'].startswith('/wiki/'): 
            print(link['href']) # The href attributes is the destination url
else:
    # Print an error message if the request failed
    print('Error:', response.status_code)
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Data_science
# /wiki/Talk:Data_science
# /wiki/Data_science
# /wiki/Data_science
# /wiki/Special:WhatLinksHere/Data_science
# /wiki/Special:RecentChangesLinked/Data_science
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /wiki/Information_science
# /wiki/File:PIA23792-1600x1200(1).jpg
# /wiki/Comet_NEOWISE
# /wiki/Astronomical_survey
# /wiki/Space_telescope
# /wiki/Wide-field_Infrared_Survey_Explorer
# /wiki/Interdisciplinary
# /wiki/Statistics
# /wiki/Scientific_computing
# /wiki/Scientific_method
# /wiki/Algorithm
# /wiki/Knowledge
# /wiki/Unstructured_data
# /wiki/Statistics
# /wiki/Data_analysis
# /wiki/Informatics
# /wiki/Scientific_method
# /wiki/Phenomena
# /wiki/Data
# /wiki/Mathematics
# /wiki/Computer_science
# /wiki/Information_science
# /wiki/Domain_knowledge
# /wiki/Computer_science
# /wiki/Turing_Award
# /wiki/Jim_Gray_(computer_scientist)
# /wiki/Empirical_research
# /wiki/Basic_research
# /wiki/Computational_science
# /wiki/Information_technology
# /wiki/Information_explosion
# /wiki/Interdisciplinarity
# /wiki/Academic_discipline
# /wiki/Knowledge_extraction
# /wiki/Big_data
# /wiki/Data_set
# /wiki/Problem-solving
# /wiki/Analysis
# /wiki/Data_visualization
# /wiki/Information_visualization
# /wiki/Data_sonification
# /wiki/Data_integration
# /wiki/Graphic_design
# /wiki/Complex_systems
# /wiki/Communication
# /wiki/Business
# /wiki/Nathan_Yau
# /wiki/Ben_Fry
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Exploration
# /wiki/American_Statistical_Association
# /wiki/Database
# /wiki/Machine_learning
# /wiki/Distributed_computing
# /wiki/Nate_Silver
# /wiki/Vasant_Dhar
# /wiki/Andrew_Gelman
# /wiki/Columbia_University
# /wiki/David_Donoho
# /wiki/John_Tukey
# /wiki/C._F._Jeff_Wu
# /wiki/Montpellier_2_University
# /wiki/Peter_Naur
# /wiki/C._F._Jeff_Wu
# /wiki/Data_mining
# /wiki/Thomas_H._Davenport
# /wiki/DJ_Patil
# /wiki/New_York_Times
# /wiki/Boston_Globe
# /wiki/William_S._Cleveland
# /wiki/Committee_on_Data_for_Science_and_Technology
# /wiki/American_Statistical_Association
# /wiki/DJ_Patil
# /wiki/Jeff_Hammerbacher
# /wiki/National_Science_Board
# /wiki/Data_collection
# /wiki/Buzzword
# /wiki/Big_data
# /wiki/File:EDA_example_-_Always_plot_your_data.jpg
# /wiki/Exploratory_data_analysis
# /wiki/Datasaurus_dozen
# /wiki/Data_management
# /wiki/Interdisciplinary_field
# /wiki/Machine_learning
# /wiki/Data_cleaning
# /wiki/Data_visualization
# /wiki/Variable_(research)
# /wiki/Data_analyst
# /wiki/Iterative
# /wiki/Unstructured_data
# /wiki/Machine_learning
# /wiki/Statistical_analysis
# /wiki/Data_preprocessing
# /wiki/Feature_engineering
# /wiki/Machine_learning_algorithms
# /wiki/Computer_science
# /wiki/Domain_expertise
# /wiki/Computer_programming
# /wiki/Data_visualization
# /wiki/Critical_thinking
# /wiki/Domain_knowledge
# /wiki/Data_management
# /wiki/Structured_data
# /wiki/Statistical_analysis
# /wiki/Machine_learning
# /wiki/Decision-making
# /wiki/File:Wiki_letter_w_cropped.svg
# /wiki/ODSC
# /wiki/Scientific_Data_(journal)
# /wiki/Women_in_Data
# /wiki/Python_(programming_language)
# /wiki/R_(programming_language)
# /wiki/Data_engineering
# /wiki/Big_data
# /wiki/Machine_learning
# /wiki/Journal_of_Computational_and_Graphical_Statistics
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9784431702085
# /wiki/ArXiv_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-9825442-0-4
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Harvard_Business_Review
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/American_Statistical_Association
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/0-12-241770-4
# /wiki/OCLC_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Harvard_Business_Review
# /wiki/New_York_Times
# /wiki/New_York_City
# /wiki/Boston_Globe
# /wiki/Boston
# /wiki/Harvard_Business_Review
# /wiki/American_Statistical_Association
# /wiki/ISSN_(identifier)
# /wiki/Forbes
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780123814791
# /wiki/Template:Data
# /wiki/Template_talk:Data
# /wiki/Special:EditPage/Template:Data
# /wiki/Data_(computer_science)
# /wiki/Data_acquisition
# /wiki/Data_augmentation
# /wiki/Data_analysis
# /wiki/Data_archaeology
# /wiki/Big_data
# /wiki/Data_cleansing
# /wiki/Data_collection
# /wiki/Data_compression
# /wiki/Data_corruption
# /wiki/Data_curation
# /wiki/Data_degradation
# /wiki/Data_editing
# /wiki/Extract,_transform,_load
# /wiki/Extract,_load,_transform
# /wiki/Data_extraction
# /wiki/Data_transformation
# /wiki/Data_loading
# /wiki/Data_farming
# /wiki/Data_format_management
# /wiki/Data_fusion
# /wiki/Data_integration
# /wiki/Data_integrity
# /wiki/Data_library
# /wiki/Data_lineage
# /wiki/Data_loss
# /wiki/Data_management
# /wiki/Data_migration
# /wiki/Data_mining
# /wiki/Data_philanthropy
# /wiki/Data_pre-processing
# /wiki/Data_preservation
# /wiki/Data_processing
# /wiki/Information_privacy
# /wiki/Data_publishing
# /wiki/Data_recovery
# /wiki/Data_reduction
# /wiki/Data_retention
# /wiki/Data_quality
# /wiki/Data_scraping
# /wiki/Data_scrubbing
# /wiki/Data_security
# /wiki/Data_steward
# /wiki/Data_storage
# /wiki/Data_synchronization
# /wiki/Data_validation
# /wiki/Data_warehouse
# /wiki/Data_wrangling
# /wiki/Help:Category
# /wiki/Category:Information_science
# /wiki/Category:Computer_occupations
# /wiki/Category:Computational_fields_of_study
# /wiki/Category:Data_analysis
# /wiki/Category:Data_science
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Use_dmy_dates_from_August_2023
# /wiki/Category:Articles_to_be_expanded_from_August_2023
# /wiki/Category:All_articles_to_be_expanded
# /wiki/Category:Articles_using_small_message_boxes
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer

# %% [markdown]
# Among those links, we can find that many links contain a colon(:). These links are not actually wiki pages but about some special services. We need to filter them out.
#
# Also, there is a link "/wiki/Main_Page" pointing to the wikipedia homepage. We don't need it.

# %%
# Send a GET request to a URL
response = requests.get("https://en.wikipedia.org/wiki/Data_science")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print all links on the web page
    links = soup.find_all('a', href=True) # href=True requires a link should have href attribute
    for link in links:
        if link['href'].startswith('/wiki/') and ':' not in link['href'] and 'Main_Page' not in link['href']:
            print(link['href']) # The href attributes is the destination url
else:
    # Print an error message if the request failed
    print('Error:', response.status_code)
# Out:
# /wiki/Data_science
# /wiki/Data_science
# /wiki/Data_science
# /wiki/Information_science
# /wiki/Comet_NEOWISE
# /wiki/Astronomical_survey
# /wiki/Space_telescope
# /wiki/Wide-field_Infrared_Survey_Explorer
# /wiki/Interdisciplinary
# /wiki/Statistics
# /wiki/Scientific_computing
# /wiki/Scientific_method
# /wiki/Algorithm
# /wiki/Knowledge
# /wiki/Unstructured_data
# /wiki/Statistics
# /wiki/Data_analysis
# /wiki/Informatics
# /wiki/Scientific_method
# /wiki/Phenomena
# /wiki/Data
# /wiki/Mathematics
# /wiki/Computer_science
# /wiki/Information_science
# /wiki/Domain_knowledge
# /wiki/Computer_science
# /wiki/Turing_Award
# /wiki/Jim_Gray_(computer_scientist)
# /wiki/Empirical_research
# /wiki/Basic_research
# /wiki/Computational_science
# /wiki/Information_technology
# /wiki/Information_explosion
# /wiki/Interdisciplinarity
# /wiki/Academic_discipline
# /wiki/Knowledge_extraction
# /wiki/Big_data
# /wiki/Data_set
# /wiki/Problem-solving
# /wiki/Analysis
# /wiki/Data_visualization
# /wiki/Information_visualization
# /wiki/Data_sonification
# /wiki/Data_integration
# /wiki/Graphic_design
# /wiki/Complex_systems
# /wiki/Communication
# /wiki/Business
# /wiki/Nathan_Yau
# /wiki/Ben_Fry
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Exploration
# /wiki/American_Statistical_Association
# /wiki/Database
# /wiki/Machine_learning
# /wiki/Distributed_computing
# /wiki/Nate_Silver
# /wiki/Vasant_Dhar
# /wiki/Andrew_Gelman
# /wiki/Columbia_University
# /wiki/David_Donoho
# /wiki/John_Tukey
# /wiki/C._F._Jeff_Wu
# /wiki/Montpellier_2_University
# /wiki/Peter_Naur
# /wiki/C._F._Jeff_Wu
# /wiki/Data_mining
# /wiki/Thomas_H._Davenport
# /wiki/DJ_Patil
# /wiki/New_York_Times
# /wiki/Boston_Globe
# /wiki/William_S._Cleveland
# /wiki/Committee_on_Data_for_Science_and_Technology
# /wiki/American_Statistical_Association
# /wiki/DJ_Patil
# /wiki/Jeff_Hammerbacher
# /wiki/National_Science_Board
# /wiki/Data_collection
# /wiki/Buzzword
# /wiki/Big_data
# /wiki/Exploratory_data_analysis
# /wiki/Datasaurus_dozen
# /wiki/Data_management
# /wiki/Interdisciplinary_field
# /wiki/Machine_learning
# /wiki/Data_cleaning
# /wiki/Data_visualization
# /wiki/Variable_(research)
# /wiki/Data_analyst
# /wiki/Iterative
# /wiki/Unstructured_data
# /wiki/Machine_learning
# /wiki/Statistical_analysis
# /wiki/Data_preprocessing
# /wiki/Feature_engineering
# /wiki/Machine_learning_algorithms
# /wiki/Computer_science
# /wiki/Domain_expertise
# /wiki/Computer_programming
# /wiki/Data_visualization
# /wiki/Critical_thinking
# /wiki/Domain_knowledge
# /wiki/Data_management
# /wiki/Structured_data
# /wiki/Statistical_analysis
# /wiki/Machine_learning
# /wiki/Decision-making
# /wiki/ODSC
# /wiki/Scientific_Data_(journal)
# /wiki/Women_in_Data
# /wiki/Python_(programming_language)
# /wiki/R_(programming_language)
# /wiki/Data_engineering
# /wiki/Big_data
# /wiki/Machine_learning
# /wiki/Journal_of_Computational_and_Graphical_Statistics
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ArXiv_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Harvard_Business_Review
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/American_Statistical_Association
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/OCLC_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Harvard_Business_Review
# /wiki/New_York_Times
# /wiki/New_York_City
# /wiki/Boston_Globe
# /wiki/Boston
# /wiki/Harvard_Business_Review
# /wiki/American_Statistical_Association
# /wiki/ISSN_(identifier)
# /wiki/Forbes
# /wiki/ISBN_(identifier)
# /wiki/Data_(computer_science)
# /wiki/Data_acquisition
# /wiki/Data_augmentation
# /wiki/Data_analysis
# /wiki/Data_archaeology
# /wiki/Big_data
# /wiki/Data_cleansing
# /wiki/Data_collection
# /wiki/Data_compression
# /wiki/Data_corruption
# /wiki/Data_curation
# /wiki/Data_degradation
# /wiki/Data_editing
# /wiki/Extract,_transform,_load
# /wiki/Extract,_load,_transform
# /wiki/Data_extraction
# /wiki/Data_transformation
# /wiki/Data_loading
# /wiki/Data_farming
# /wiki/Data_format_management
# /wiki/Data_fusion
# /wiki/Data_integration
# /wiki/Data_integrity
# /wiki/Data_library
# /wiki/Data_lineage
# /wiki/Data_loss
# /wiki/Data_management
# /wiki/Data_migration
# /wiki/Data_mining
# /wiki/Data_philanthropy
# /wiki/Data_pre-processing
# /wiki/Data_preservation
# /wiki/Data_processing
# /wiki/Information_privacy
# /wiki/Data_publishing
# /wiki/Data_recovery
# /wiki/Data_reduction
# /wiki/Data_retention
# /wiki/Data_quality
# /wiki/Data_scraping
# /wiki/Data_scrubbing
# /wiki/Data_security
# /wiki/Data_steward
# /wiki/Data_storage
# /wiki/Data_synchronization
# /wiki/Data_validation
# /wiki/Data_warehouse
# /wiki/Data_wrangling

# %% [markdown]
# Now, each link points to a wikipedia page about some topic. However, those links are relative links, i.e., they do not have the domain name. We can add the wikipedia domain name at the front to make them full web urls.

# %%
# Send a GET request to a URL
response = requests.get("https://en.wikipedia.org/wiki/Data_science")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print all links on the web page
    links = soup.find_all('a', href=True) # href=True requires a link should have href attribute
    for link in links:
        if link['href'].startswith('/wiki/') and ':' not in link['href'] and 'Main_Page' not in link['href']:
            print(f"https://en.wikipedia.org{link['href']}") # Full link
else:
    # Print an error message if the request failed
    print('Error:', response.status_code)
# Out:
# https://en.wikipedia.org/wiki/Data_science
# https://en.wikipedia.org/wiki/Data_science
# https://en.wikipedia.org/wiki/Data_science
# https://en.wikipedia.org/wiki/Information_science
# https://en.wikipedia.org/wiki/Comet_NEOWISE
# https://en.wikipedia.org/wiki/Astronomical_survey
# https://en.wikipedia.org/wiki/Space_telescope
# https://en.wikipedia.org/wiki/Wide-field_Infrared_Survey_Explorer
# https://en.wikipedia.org/wiki/Interdisciplinary
# https://en.wikipedia.org/wiki/Statistics
# https://en.wikipedia.org/wiki/Scientific_computing
# https://en.wikipedia.org/wiki/Scientific_method
# https://en.wikipedia.org/wiki/Algorithm
# https://en.wikipedia.org/wiki/Knowledge
# https://en.wikipedia.org/wiki/Unstructured_data
# https://en.wikipedia.org/wiki/Statistics
# https://en.wikipedia.org/wiki/Data_analysis
# https://en.wikipedia.org/wiki/Informatics
# https://en.wikipedia.org/wiki/Scientific_method
# https://en.wikipedia.org/wiki/Phenomena
# https://en.wikipedia.org/wiki/Data
# https://en.wikipedia.org/wiki/Mathematics
# https://en.wikipedia.org/wiki/Computer_science
# https://en.wikipedia.org/wiki/Information_science
# https://en.wikipedia.org/wiki/Domain_knowledge
# https://en.wikipedia.org/wiki/Computer_science
# https://en.wikipedia.org/wiki/Turing_Award
# https://en.wikipedia.org/wiki/Jim_Gray_(computer_scientist)
# https://en.wikipedia.org/wiki/Empirical_research
# https://en.wikipedia.org/wiki/Basic_research
# https://en.wikipedia.org/wiki/Computational_science
# https://en.wikipedia.org/wiki/Information_technology
# https://en.wikipedia.org/wiki/Information_explosion
# https://en.wikipedia.org/wiki/Interdisciplinarity
# https://en.wikipedia.org/wiki/Academic_discipline
# https://en.wikipedia.org/wiki/Knowledge_extraction
# https://en.wikipedia.org/wiki/Big_data
# https://en.wikipedia.org/wiki/Data_set
# https://en.wikipedia.org/wiki/Problem-solving
# https://en.wikipedia.org/wiki/Analysis
# https://en.wikipedia.org/wiki/Data_visualization
# https://en.wikipedia.org/wiki/Information_visualization
# https://en.wikipedia.org/wiki/Data_sonification
# https://en.wikipedia.org/wiki/Data_integration
# https://en.wikipedia.org/wiki/Graphic_design
# https://en.wikipedia.org/wiki/Complex_systems
# https://en.wikipedia.org/wiki/Communication
# https://en.wikipedia.org/wiki/Business
# https://en.wikipedia.org/wiki/Nathan_Yau
# https://en.wikipedia.org/wiki/Ben_Fry
# https://en.wikipedia.org/wiki/Human%E2%80%93computer_interaction
# https://en.wikipedia.org/wiki/Exploration
# https://en.wikipedia.org/wiki/American_Statistical_Association
# https://en.wikipedia.org/wiki/Database
# https://en.wikipedia.org/wiki/Machine_learning
# https://en.wikipedia.org/wiki/Distributed_computing
# https://en.wikipedia.org/wiki/Nate_Silver
# https://en.wikipedia.org/wiki/Vasant_Dhar
# https://en.wikipedia.org/wiki/Andrew_Gelman
# https://en.wikipedia.org/wiki/Columbia_University
# https://en.wikipedia.org/wiki/David_Donoho
# https://en.wikipedia.org/wiki/John_Tukey
# https://en.wikipedia.org/wiki/C._F._Jeff_Wu
# https://en.wikipedia.org/wiki/Montpellier_2_University
# https://en.wikipedia.org/wiki/Peter_Naur
# https://en.wikipedia.org/wiki/C._F._Jeff_Wu
# https://en.wikipedia.org/wiki/Data_mining
# https://en.wikipedia.org/wiki/Thomas_H._Davenport
# https://en.wikipedia.org/wiki/DJ_Patil
# https://en.wikipedia.org/wiki/New_York_Times
# https://en.wikipedia.org/wiki/Boston_Globe
# https://en.wikipedia.org/wiki/William_S._Cleveland
# https://en.wikipedia.org/wiki/Committee_on_Data_for_Science_and_Technology
# https://en.wikipedia.org/wiki/American_Statistical_Association
# https://en.wikipedia.org/wiki/DJ_Patil
# https://en.wikipedia.org/wiki/Jeff_Hammerbacher
# https://en.wikipedia.org/wiki/National_Science_Board
# https://en.wikipedia.org/wiki/Data_collection
# https://en.wikipedia.org/wiki/Buzzword
# https://en.wikipedia.org/wiki/Big_data
# https://en.wikipedia.org/wiki/Exploratory_data_analysis
# https://en.wikipedia.org/wiki/Datasaurus_dozen
# https://en.wikipedia.org/wiki/Data_management
# https://en.wikipedia.org/wiki/Interdisciplinary_field
# https://en.wikipedia.org/wiki/Machine_learning
# https://en.wikipedia.org/wiki/Data_cleaning
# https://en.wikipedia.org/wiki/Data_visualization
# https://en.wikipedia.org/wiki/Variable_(research)
# https://en.wikipedia.org/wiki/Data_analyst
# https://en.wikipedia.org/wiki/Iterative
# https://en.wikipedia.org/wiki/Unstructured_data
# https://en.wikipedia.org/wiki/Machine_learning
# https://en.wikipedia.org/wiki/Statistical_analysis
# https://en.wikipedia.org/wiki/Data_preprocessing
# https://en.wikipedia.org/wiki/Feature_engineering
# https://en.wikipedia.org/wiki/Machine_learning_algorithms
# https://en.wikipedia.org/wiki/Computer_science
# https://en.wikipedia.org/wiki/Domain_expertise
# https://en.wikipedia.org/wiki/Computer_programming
# https://en.wikipedia.org/wiki/Data_visualization
# https://en.wikipedia.org/wiki/Critical_thinking
# https://en.wikipedia.org/wiki/Domain_knowledge
# https://en.wikipedia.org/wiki/Data_management
# https://en.wikipedia.org/wiki/Structured_data
# https://en.wikipedia.org/wiki/Statistical_analysis
# https://en.wikipedia.org/wiki/Machine_learning
# https://en.wikipedia.org/wiki/Decision-making
# https://en.wikipedia.org/wiki/ODSC
# https://en.wikipedia.org/wiki/Scientific_Data_(journal)
# https://en.wikipedia.org/wiki/Women_in_Data
# https://en.wikipedia.org/wiki/Python_(programming_language)
# https://en.wikipedia.org/wiki/R_(programming_language)
# https://en.wikipedia.org/wiki/Data_engineering
# https://en.wikipedia.org/wiki/Big_data
# https://en.wikipedia.org/wiki/Machine_learning
# https://en.wikipedia.org/wiki/Journal_of_Computational_and_Graphical_Statistics
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/S2CID_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/S2CID_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/ISSN_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ArXiv_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/ISSN_(identifier)
# https://en.wikipedia.org/wiki/S2CID_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/ISSN_(identifier)
# https://en.wikipedia.org/wiki/PMID_(identifier)
# https://en.wikipedia.org/wiki/S2CID_(identifier)
# https://en.wikipedia.org/wiki/Harvard_Business_Review
# https://en.wikipedia.org/wiki/PMID_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/American_Statistical_Association
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/S2CID_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/OCLC_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Harvard_Business_Review
# https://en.wikipedia.org/wiki/New_York_Times
# https://en.wikipedia.org/wiki/New_York_City
# https://en.wikipedia.org/wiki/Boston_Globe
# https://en.wikipedia.org/wiki/Boston
# https://en.wikipedia.org/wiki/Harvard_Business_Review
# https://en.wikipedia.org/wiki/American_Statistical_Association
# https://en.wikipedia.org/wiki/ISSN_(identifier)
# https://en.wikipedia.org/wiki/Forbes
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/Data_(computer_science)
# https://en.wikipedia.org/wiki/Data_acquisition
# https://en.wikipedia.org/wiki/Data_augmentation
# https://en.wikipedia.org/wiki/Data_analysis
# https://en.wikipedia.org/wiki/Data_archaeology
# https://en.wikipedia.org/wiki/Big_data
# https://en.wikipedia.org/wiki/Data_cleansing
# https://en.wikipedia.org/wiki/Data_collection
# https://en.wikipedia.org/wiki/Data_compression
# https://en.wikipedia.org/wiki/Data_corruption
# https://en.wikipedia.org/wiki/Data_curation
# https://en.wikipedia.org/wiki/Data_degradation
# https://en.wikipedia.org/wiki/Data_editing
# https://en.wikipedia.org/wiki/Extract,_transform,_load
# https://en.wikipedia.org/wiki/Extract,_load,_transform
# https://en.wikipedia.org/wiki/Data_extraction
# https://en.wikipedia.org/wiki/Data_transformation
# https://en.wikipedia.org/wiki/Data_loading
# https://en.wikipedia.org/wiki/Data_farming
# https://en.wikipedia.org/wiki/Data_format_management
# https://en.wikipedia.org/wiki/Data_fusion
# https://en.wikipedia.org/wiki/Data_integration
# https://en.wikipedia.org/wiki/Data_integrity
# https://en.wikipedia.org/wiki/Data_library
# https://en.wikipedia.org/wiki/Data_lineage
# https://en.wikipedia.org/wiki/Data_loss
# https://en.wikipedia.org/wiki/Data_management
# https://en.wikipedia.org/wiki/Data_migration
# https://en.wikipedia.org/wiki/Data_mining
# https://en.wikipedia.org/wiki/Data_philanthropy
# https://en.wikipedia.org/wiki/Data_pre-processing
# https://en.wikipedia.org/wiki/Data_preservation
# https://en.wikipedia.org/wiki/Data_processing
# https://en.wikipedia.org/wiki/Information_privacy
# https://en.wikipedia.org/wiki/Data_publishing
# https://en.wikipedia.org/wiki/Data_recovery
# https://en.wikipedia.org/wiki/Data_reduction
# https://en.wikipedia.org/wiki/Data_retention
# https://en.wikipedia.org/wiki/Data_quality
# https://en.wikipedia.org/wiki/Data_scraping
# https://en.wikipedia.org/wiki/Data_scrubbing
# https://en.wikipedia.org/wiki/Data_security
# https://en.wikipedia.org/wiki/Data_steward
# https://en.wikipedia.org/wiki/Data_storage
# https://en.wikipedia.org/wiki/Data_synchronization
# https://en.wikipedia.org/wiki/Data_validation
# https://en.wikipedia.org/wiki/Data_warehouse
# https://en.wikipedia.org/wiki/Data_wrangling

# %% [markdown]
# ### Save a Webpage
# After a webpage is crawled, we can use the following code to save it to our local disk.

# %%
import os

# Send a GET request to a URL
response = requests.get("https://en.wikipedia.org/wiki/Data_science")

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract the title of the web page
    title = soup.title.text 

    # Create a folder to store webpages
    if not os.path.exists("pages"): 
        os.mkdir("pages")
    
    file_name = f"{title}.html"
    file_path = os.path.join("pages", file_name)

    # Save the webpage
    with open(file_path, 'w', encoding='utf-8', errors="ignore") as f:
        f.write(response.text)

    
else:
    # Print an error message if the request failed
    print('Error:', response.status_code)

# %% [markdown]
# ### Use a Queue to Crawl Webpages Continuously
# The above code pieces show how to download and save one single wikipedia page and extract all the links within the page that point to other wiki pages. Now, we will use a queue to continuously downloading and saving wiki pages following the links. Below are the major steps.
#
# 1. Initialize the queue with a seed url.
# 2. Pop an url from the queue.
# 3. Download the save the wiki page with the above url.
# 4. Extract all urls that link to another wiki page from the downloaded page.
# 5. Push those urls into the queue.
# 6. Repeat step 2-5, until a certain number of wiki pages are downloaded.

# %%
queue = ["https://en.wikipedia.org/wiki/Data_science"] # Use a Python array as queue

max_pages = 100 # max number of wiki pages we need to download

visited_urls = set()

if not os.path.exists("pages"):
    os.makedirs("pages")

while queue and len(visited_urls) < max_pages:
    url = queue.pop(0) # Pop the last element in the array

    # Avoid revisiting visited urls. 
    if url in visited_urls:
        continue

    visited_urls.add(url) 

    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the title of the web page
        title = soup.title.text 

        file_name = f"{title}.html"
        file_path = os.path.join("pages", file_name)

        # Save the webpage
        with open(file_path, 'w', encoding='utf-8', errors="ignore") as f:
            f.write(response.text)
        
        # Find links to other Wikipedia pages
        links = soup.find_all('a', href=True) 
        for link in links:
            if link['href'].startswith('/wiki/') and ':' not in link['href'] and 'Main_Page' not in link['href']:
                queue.append(f"https://en.wikipedia.org{link['href']}") # Push new links into the queue
        
    except Exception as e:
        print(f"Error occurred while crawling {url}: {e}")

print("Crawling complete!")
# Out:
# Crawling complete!

# %% [markdown]
# ### Wrap up the Crawler
# Now, we will wrap up the above code as a single function to crawl and downloaded wiki pages.

# %%
import requests 
from bs4 import BeautifulSoup 
import os
import time

def crawl_wiki(seed_urls, max_pages, destination_folder):

    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    queue = []
    for url in seed_urls:
        queue.append(url)
    visited_urls = set()

    while queue and len(visited_urls) < max_pages:
        url = queue.pop(0)
        if url in visited_urls:
            continue
        visited_urls.add(url) 

        try:
            response = requests.get(url)
            time.sleep(1) # Add a polite policy to reduce the rate of visiting the wiki server.

            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract the title of the web page
            title = soup.title.text 

            file_name = f"{title}.html"
            file_path = os.path.join(destination_folder, file_name)

            # Save the webpage
            with open(file_path, 'w', encoding='utf-8', errors="ignore") as f:
                f.write(response.text)
                print(f"{url} saved.")
            
            # Find links to other Wikipedia pages
            links = soup.find_all('a', href=True) 
            for link in links:
                href = link['href']
                if href.startswith('/wiki/') and ':' not in href and 'Main_Page' not in href:
                    queue.append(f"https://en.wikipedia.org{href}") # Push new links into the queue
            
        except Exception as e:
            print(f"Error occurred while crawling {url}: {e}")

    print("Crawling complete!")

# %%
# Test the crawling function
seed_urls = ["https://en.wikipedia.org/wiki/Data_science"]
max_pages = 500
destination_folder = "pages"
crawl_wiki(seed_urls, max_pages, destination_folder)
# Out:
# https://en.wikipedia.org/wiki/Data_science saved.
# https://en.wikipedia.org/wiki/Information_science saved.
# https://en.wikipedia.org/wiki/Comet_NEOWISE saved.
# https://en.wikipedia.org/wiki/Astronomical_survey saved.
# https://en.wikipedia.org/wiki/Space_telescope saved.
# https://en.wikipedia.org/wiki/Wide-field_Infrared_Survey_Explorer saved.
# https://en.wikipedia.org/wiki/Interdisciplinary saved.
# https://en.wikipedia.org/wiki/Statistics saved.
# https://en.wikipedia.org/wiki/Scientific_computing saved.
# https://en.wikipedia.org/wiki/Scientific_method saved.
# https://en.wikipedia.org/wiki/Algorithm saved.
# https://en.wikipedia.org/wiki/Knowledge saved.
# https://en.wikipedia.org/wiki/Unstructured_data saved.
# https://en.wikipedia.org/wiki/Data_analysis saved.
# https://en.wikipedia.org/wiki/Informatics saved.
# https://en.wikipedia.org/wiki/Phenomena saved.
# https://en.wikipedia.org/wiki/Data saved.
# https://en.wikipedia.org/wiki/Mathematics saved.
# https://en.wikipedia.org/wiki/Computer_science saved.
# https://en.wikipedia.org/wiki/Domain_knowledge saved.
# https://en.wikipedia.org/wiki/Turing_Award saved.
# https://en.wikipedia.org/wiki/Jim_Gray_(computer_scientist) saved.
# https://en.wikipedia.org/wiki/Empirical_research saved.
# https://en.wikipedia.org/wiki/Basic_research saved.
# https://en.wikipedia.org/wiki/Computational_science saved.
# https://en.wikipedia.org/wiki/Information_technology saved.
# https://en.wikipedia.org/wiki/Information_explosion saved.
# https://en.wikipedia.org/wiki/Interdisciplinarity saved.
# https://en.wikipedia.org/wiki/Academic_discipline saved.
# https://en.wikipedia.org/wiki/Knowledge_extraction saved.
# https://en.wikipedia.org/wiki/Big_data saved.
# https://en.wikipedia.org/wiki/Data_set saved.
# https://en.wikipedia.org/wiki/Problem-solving saved.
# https://en.wikipedia.org/wiki/Analysis saved.
# https://en.wikipedia.org/wiki/Data_visualization saved.
# https://en.wikipedia.org/wiki/Information_visualization saved.
# https://en.wikipedia.org/wiki/Data_sonification saved.
# https://en.wikipedia.org/wiki/Data_integration saved.
# https://en.wikipedia.org/wiki/Graphic_design saved.
# https://en.wikipedia.org/wiki/Complex_systems saved.
# https://en.wikipedia.org/wiki/Communication saved.
# https://en.wikipedia.org/wiki/Business saved.
# https://en.wikipedia.org/wiki/Nathan_Yau saved.
# https://en.wikipedia.org/wiki/Ben_Fry saved.
# https://en.wikipedia.org/wiki/Human%E2%80%93computer_interaction saved.
# https://en.wikipedia.org/wiki/Exploration saved.
# https://en.wikipedia.org/wiki/American_Statistical_Association saved.
# https://en.wikipedia.org/wiki/Database saved.
# https://en.wikipedia.org/wiki/Machine_learning saved.
# https://en.wikipedia.org/wiki/Distributed_computing saved.
# https://en.wikipedia.org/wiki/Nate_Silver saved.
# https://en.wikipedia.org/wiki/Vasant_Dhar saved.
# https://en.wikipedia.org/wiki/Andrew_Gelman saved.
# https://en.wikipedia.org/wiki/Columbia_University saved.
# https://en.wikipedia.org/wiki/David_Donoho saved.
# https://en.wikipedia.org/wiki/John_Tukey saved.
# https://en.wikipedia.org/wiki/C._F._Jeff_Wu saved.
# https://en.wikipedia.org/wiki/Montpellier_2_University saved.
# https://en.wikipedia.org/wiki/Peter_Naur saved.
# https://en.wikipedia.org/wiki/Data_mining saved.
# https://en.wikipedia.org/wiki/Thomas_H._Davenport saved.
# https://en.wikipedia.org/wiki/DJ_Patil saved.
# https://en.wikipedia.org/wiki/New_York_Times saved.
# https://en.wikipedia.org/wiki/Boston_Globe saved.
# https://en.wikipedia.org/wiki/William_S._Cleveland saved.
# https://en.wikipedia.org/wiki/Committee_on_Data_for_Science_and_Technology saved.
# https://en.wikipedia.org/wiki/Jeff_Hammerbacher saved.
# https://en.wikipedia.org/wiki/National_Science_Board saved.
# https://en.wikipedia.org/wiki/Data_collection saved.
# https://en.wikipedia.org/wiki/Buzzword saved.
# https://en.wikipedia.org/wiki/Exploratory_data_analysis saved.
# https://en.wikipedia.org/wiki/Datasaurus_dozen saved.
# https://en.wikipedia.org/wiki/Data_management saved.
# https://en.wikipedia.org/wiki/Interdisciplinary_field saved.
# https://en.wikipedia.org/wiki/Data_cleaning saved.
# https://en.wikipedia.org/wiki/Variable_(research) saved.
# https://en.wikipedia.org/wiki/Data_analyst saved.
# https://en.wikipedia.org/wiki/Iterative saved.
# https://en.wikipedia.org/wiki/Statistical_analysis saved.
# https://en.wikipedia.org/wiki/Data_preprocessing saved.
# https://en.wikipedia.org/wiki/Feature_engineering saved.
# https://en.wikipedia.org/wiki/Machine_learning_algorithms saved.
# https://en.wikipedia.org/wiki/Domain_expertise saved.
# https://en.wikipedia.org/wiki/Computer_programming saved.
# https://en.wikipedia.org/wiki/Critical_thinking saved.
# https://en.wikipedia.org/wiki/Structured_data saved.
# https://en.wikipedia.org/wiki/Decision-making saved.
# https://en.wikipedia.org/wiki/ODSC saved.
# https://en.wikipedia.org/wiki/Scientific_Data_(journal) saved.
# https://en.wikipedia.org/wiki/Women_in_Data saved.
# https://en.wikipedia.org/wiki/Python_(programming_language) saved.
# https://en.wikipedia.org/wiki/R_(programming_language) saved.
# https://en.wikipedia.org/wiki/Data_engineering saved.
# https://en.wikipedia.org/wiki/Journal_of_Computational_and_Graphical_Statistics saved.
# https://en.wikipedia.org/wiki/Doi_(identifier) saved.
# https://en.wikipedia.org/wiki/S2CID_(identifier) saved.
# https://en.wikipedia.org/wiki/ISSN_(identifier) saved.
# https://en.wikipedia.org/wiki/ISBN_(identifier) saved.
# https://en.wikipedia.org/wiki/ArXiv_(identifier) saved.
# https://en.wikipedia.org/wiki/PMID_(identifier) saved.
# https://en.wikipedia.org/wiki/Harvard_Business_Review saved.
# https://en.wikipedia.org/wiki/OCLC_(identifier) saved.
# https://en.wikipedia.org/wiki/New_York_City saved.
# https://en.wikipedia.org/wiki/Boston saved.
# https://en.wikipedia.org/wiki/Forbes saved.
# https://en.wikipedia.org/wiki/Data_(computer_science) saved.
# https://en.wikipedia.org/wiki/Data_acquisition saved.
# https://en.wikipedia.org/wiki/Data_augmentation saved.
# https://en.wikipedia.org/wiki/Data_archaeology saved.
# https://en.wikipedia.org/wiki/Data_cleansing saved.
# https://en.wikipedia.org/wiki/Data_compression saved.
# https://en.wikipedia.org/wiki/Data_corruption saved.
# https://en.wikipedia.org/wiki/Data_curation saved.
# https://en.wikipedia.org/wiki/Data_degradation saved.
# https://en.wikipedia.org/wiki/Data_editing saved.
# https://en.wikipedia.org/wiki/Extract,_transform,_load saved.
# https://en.wikipedia.org/wiki/Extract,_load,_transform saved.
# https://en.wikipedia.org/wiki/Data_extraction saved.
# https://en.wikipedia.org/wiki/Data_transformation saved.
# https://en.wikipedia.org/wiki/Data_loading saved.
# https://en.wikipedia.org/wiki/Data_farming saved.
# https://en.wikipedia.org/wiki/Data_format_management saved.
# https://en.wikipedia.org/wiki/Data_fusion saved.
# https://en.wikipedia.org/wiki/Data_integrity saved.
# https://en.wikipedia.org/wiki/Data_library saved.
# https://en.wikipedia.org/wiki/Data_lineage saved.
# https://en.wikipedia.org/wiki/Data_loss saved.
# https://en.wikipedia.org/wiki/Data_migration saved.
# https://en.wikipedia.org/wiki/Data_philanthropy saved.
# https://en.wikipedia.org/wiki/Data_pre-processing saved.
# https://en.wikipedia.org/wiki/Data_preservation saved.
# https://en.wikipedia.org/wiki/Data_processing saved.
# https://en.wikipedia.org/wiki/Information_privacy saved.
# https://en.wikipedia.org/wiki/Data_publishing saved.
# https://en.wikipedia.org/wiki/Data_recovery saved.
# https://en.wikipedia.org/wiki/Data_reduction saved.
# https://en.wikipedia.org/wiki/Data_retention saved.
# https://en.wikipedia.org/wiki/Data_quality saved.
# https://en.wikipedia.org/wiki/Data_scraping saved.
# https://en.wikipedia.org/wiki/Data_scrubbing saved.
# https://en.wikipedia.org/wiki/Data_security saved.
# https://en.wikipedia.org/wiki/Data_steward saved.
# https://en.wikipedia.org/wiki/Data_storage saved.
# https://en.wikipedia.org/wiki/Data_synchronization saved.
# https://en.wikipedia.org/wiki/Data_validation saved.
# https://en.wikipedia.org/wiki/Data_warehouse saved.
# https://en.wikipedia.org/wiki/Data_wrangling saved.
# https://en.wikipedia.org/wiki/Information_theory saved.
# https://en.wikipedia.org/wiki/Information_engineering_(field) saved.
# https://en.wikipedia.org/wiki/Library_science saved.
# https://en.wikipedia.org/wiki/Information_system#As_an_academic_discipline saved.
# https://en.wikipedia.org/wiki/Information_Sciences_(journal) saved.
# https://en.wikipedia.org/wiki/Outline_of_information_science saved.
# https://en.wikipedia.org/wiki/Information_access saved.
# https://en.wikipedia.org/wiki/Information_architecture saved.
# https://en.wikipedia.org/wiki/Information_behavior saved.
# https://en.wikipedia.org/wiki/Information_management saved.
# https://en.wikipedia.org/wiki/Information_retrieval saved.
# https://en.wikipedia.org/wiki/Information_seeking saved.
# https://en.wikipedia.org/wiki/Information_society saved.
# https://en.wikipedia.org/wiki/Knowledge_organization saved.
# https://en.wikipedia.org/wiki/Ontology_(computer_science) saved.
# https://en.wikipedia.org/wiki/Philosophy_of_information saved.
# https://en.wikipedia.org/wiki/Science_and_technology_studies saved.
# https://en.wikipedia.org/wiki/Taxonomy saved.
# https://en.wikipedia.org/wiki/Bibliometrics saved.
# https://en.wikipedia.org/wiki/Categorization saved.
# https://en.wikipedia.org/wiki/Censorship saved.
# https://en.wikipedia.org/wiki/Classification_of_the_sciences_(Peirce) saved.
# https://en.wikipedia.org/wiki/Computer_data_storage saved.
# https://en.wikipedia.org/wiki/Cultural_studies saved.
# https://en.wikipedia.org/wiki/Data_modeling saved.
# https://en.wikipedia.org/wiki/Intellectual_freedom saved.
# https://en.wikipedia.org/wiki/Intellectual_property saved.
# https://en.wikipedia.org/wiki/Library_and_information_science saved.
# https://en.wikipedia.org/wiki/Memory saved.
# https://en.wikipedia.org/wiki/Preservation_(library_and_archival_science) saved.
# https://en.wikipedia.org/wiki/Privacy saved.
# https://en.wikipedia.org/wiki/Quantum_information_science saved.
# https://en.wikipedia.org/wiki/Outline_of_library_and_information_science saved.
# https://en.wikipedia.org/wiki/Glossary_of_library_and_information_science saved.
# https://en.wikipedia.org/wiki/History_of_libraries saved.
# https://en.wikipedia.org/wiki/Information_history saved.
# https://en.wikipedia.org/wiki/Archives_management saved.
# https://en.wikipedia.org/wiki/Collections_management saved.
# https://en.wikipedia.org/wiki/Preservation_(library_and_archive) saved.
# https://en.wikipedia.org/wiki/Cataloging_(library_science) saved.
# https://en.wikipedia.org/wiki/Knowledge_management saved.
# https://en.wikipedia.org/wiki/Library_management saved.
# https://en.wikipedia.org/wiki/Metadata saved.
# https://en.wikipedia.org/wiki/Information saved.
# https://en.wikipedia.org/wiki/Document saved.
# https://en.wikipedia.org/wiki/Cultural_artifact saved.
# https://en.wikipedia.org/wiki/Archival_science saved.
# https://en.wikipedia.org/wiki/Communication_studies saved.
# https://en.wikipedia.org/wiki/Documentation_science saved.
# https://en.wikipedia.org/wiki/Epistemology saved.
# https://en.wikipedia.org/wiki/Academic_library saved.
# https://en.wikipedia.org/wiki/Archive saved.
# https://en.wikipedia.org/wiki/Law_library saved.
# https://en.wikipedia.org/wiki/Medical_library saved.
# https://en.wikipedia.org/wiki/Private_library saved.
# https://en.wikipedia.org/wiki/Public_library saved.
# https://en.wikipedia.org/wiki/School_library saved.
# https://en.wikipedia.org/wiki/Special_library saved.
# https://en.wikipedia.org/wiki/Organization saved.
# https://en.wikipedia.org/wiki/Information_system saved.
# https://en.wikipedia.org/wiki/Psychology saved.
# https://en.wikipedia.org/wiki/Technology saved.
# https://en.wikipedia.org/wiki/Healthcare saved.
# https://en.wikipedia.org/wiki/Intelligence_agency saved.
# https://en.wikipedia.org/wiki/Cognitive_science saved.
# https://en.wikipedia.org/wiki/Commerce saved.
# https://en.wikipedia.org/wiki/Law saved.
# https://en.wikipedia.org/wiki/Linguistics saved.
# https://en.wikipedia.org/wiki/Museology saved.
# https://en.wikipedia.org/wiki/Management saved.
# https://en.wikipedia.org/wiki/Philosophy saved.
# https://en.wikipedia.org/wiki/Policy saved.
# https://en.wikipedia.org/wiki/Social_sciences saved.
# https://en.wikipedia.org/wiki/Problem_solving saved.
# https://en.wikipedia.org/wiki/Technological_determinism saved.
# https://en.wikipedia.org/wiki/Sociology saved.
# https://en.wikipedia.org/wiki/List_of_I-Schools saved.
# https://en.wikipedia.org/wiki/Groupware saved.
# https://en.wikipedia.org/wiki/Semantic_Web saved.
# https://en.wikipedia.org/wiki/Value_sensitive_design saved.
# https://en.wikipedia.org/wiki/Iterative_design saved.
# https://en.wikipedia.org/wiki/Informatics_(academic_field) saved.
# https://en.wikipedia.org/wiki/Alexander_Ivanovich_Mikhailov saved.
# https://en.wikipedia.org/wiki/Medical_Informatics saved.
# https://en.wikipedia.org/wiki/Information_systems saved.
# https://en.wikipedia.org/wiki/Brian_Campbell_Vickery saved.
# https://en.wikipedia.org/wiki/Ontology_(information_science) saved.
# https://en.wikipedia.org/wiki/Domain_of_discourse saved.
# https://en.wikipedia.org/wiki/Reasoning saved.
# https://en.wikipedia.org/wiki/Vocabulary saved.
# https://en.wikipedia.org/wiki/Taxonomy_(general) saved.
# https://en.wikipedia.org/wiki/Artificial_intelligence saved.
# https://en.wikipedia.org/wiki/Systems_engineering saved.
# https://en.wikipedia.org/wiki/Software_engineering saved.
# https://en.wikipedia.org/wiki/Biomedical_informatics saved.
# https://en.wikipedia.org/wiki/Enterprise_bookmarking saved.
# https://en.wikipedia.org/wiki/Knowledge_representation saved.
# https://en.wikipedia.org/wiki/Enterprise_architecture_framework saved.
# https://en.wikipedia.org/wiki/Information_scientist saved.
# https://en.wikipedia.org/wiki/Systems_analyst saved.
# https://en.wikipedia.org/wiki/Efficiency saved.
# https://en.wikipedia.org/wiki/Productivity saved.
# https://en.wikipedia.org/wiki/Information_professional saved.
# https://en.wikipedia.org/wiki/Gottfried_Wilhelm_Leibniz saved.
# https://en.wikipedia.org/wiki/Polymath saved.
# https://en.wikipedia.org/wiki/Metaphysics saved.
# https://en.wikipedia.org/wiki/Theodicy saved.
# https://en.wikipedia.org/wiki/Assyrian_Empire saved.
# https://en.wikipedia.org/wiki/History_of_science saved.
# https://en.wikipedia.org/wiki/Philosophical_Transactions saved.
# https://en.wikipedia.org/wiki/Institutionalisation saved.
# https://en.wikipedia.org/wiki/Benjamin_Franklin saved.
# https://en.wikipedia.org/wiki/Library_Company_of_Philadelphia saved.
# https://en.wikipedia.org/wiki/Experiment saved.
# https://en.wikipedia.org/wiki/Massachusetts saved.
# https://en.wikipedia.org/wiki/United_States saved.
# https://en.wikipedia.org/wiki/Paris saved.
# https://en.wikipedia.org/wiki/Medical_journal saved.
# https://en.wikipedia.org/wiki/American_Philosophical_Society saved.
# https://en.wikipedia.org/wiki/Royal_Society saved.
# https://en.wikipedia.org/wiki/London saved.
# https://en.wikipedia.org/wiki/Alois_Senefelder saved.
# https://en.wikipedia.org/wiki/Lithography saved.
# https://en.wikipedia.org/wiki/Germany saved.
# https://en.wikipedia.org/wiki/Joseph_Marie_Jacquard saved.
# https://en.wikipedia.org/wiki/Charles_Babbage saved.
# https://en.wikipedia.org/wiki/Richard_Hoe saved.
# https://en.wikipedia.org/wiki/Samuel_Morse saved.
# https://en.wikipedia.org/wiki/George_Boole saved.
# https://en.wikipedia.org/wiki/Boolean_algebra_(logic) saved.
# https://en.wikipedia.org/wiki/Stanislao_Cannizzaro saved.
# https://en.wikipedia.org/wiki/Smithsonian_Institution saved.
# https://en.wikipedia.org/wiki/Sholes_and_Glidden_typewriter saved.
# https://en.wikipedia.org/wiki/Frank_Stephen_Baldwin saved.
# https://en.wikipedia.org/wiki/Alexander_Graham_Bell saved.
# https://en.wikipedia.org/wiki/Thomas_Edison saved.
# https://en.wikipedia.org/wiki/American_Library_Association saved.
# https://en.wikipedia.org/wiki/John_Shaw_Billings saved.
# https://en.wikipedia.org/wiki/Paul_Otlet saved.
# https://en.wikipedia.org/wiki/Henri_La_Fontaine saved.
# https://en.wikipedia.org/wiki/Second_World_War saved.
# https://en.wikipedia.org/wiki/Suzanne_Briet saved.
# https://en.wikipedia.org/wiki/Nobel_Prize saved.
# https://en.wikipedia.org/wiki/Information_technologies saved.
# https://en.wikipedia.org/wiki/League_of_Nations saved.
# https://en.wikipedia.org/wiki/United_Nations saved.
# https://en.wikipedia.org/wiki/Universal_Decimal_Classification saved.
# https://en.wikipedia.org/wiki/Melville_Dewey saved.
# https://en.wikipedia.org/wiki/World_Wide_Web saved.
# https://en.wikipedia.org/wiki/Hyperlink saved.
# https://en.wikipedia.org/wiki/Search_engine_(computing) saved.
# https://en.wikipedia.org/wiki/Social_network saved.
# https://en.wikipedia.org/wiki/American_Society_for_Information_Science_and_Technology saved.
# https://en.wikipedia.org/wiki/Vannevar_Bush saved.
# https://en.wikipedia.org/wiki/Medicine saved.
# https://en.wikipedia.org/wiki/Foster_E._Mohrhardt saved.
# https://en.wikipedia.org/wiki/National_Agricultural_Library saved.
# https://en.wikipedia.org/wiki/United_States_National_Library_of_Medicine saved.
# https://en.wikipedia.org/wiki/Dialog_(online_database) saved.
# https://en.wikipedia.org/wiki/Compuserve saved.
# https://en.wikipedia.org/wiki/Special_interest_groups saved.
# https://en.wikipedia.org/wiki/Dissemination saved.
# https://en.wikipedia.org/wiki/Internet saved.
# https://en.wikipedia.org/wiki/Online_communities saved.
# https://en.wikipedia.org/wiki/Social_media saved.
# https://en.wikipedia.org/wiki/Facebook saved.
# https://en.wikipedia.org/wiki/Twitter saved.
# https://en.wikipedia.org/wiki/The_Wall_Street_Journal saved.
# https://en.wikipedia.org/wiki/The_Washington_Post saved.
# https://en.wikipedia.org/wiki/Wikipedia saved.
# https://en.wikipedia.org/wiki/Information_Security saved.
# https://en.wikipedia.org/wiki/Language_Technology saved.
# https://en.wikipedia.org/wiki/Computer_Science saved.
# https://en.wikipedia.org/wiki/Text_mining saved.
# https://en.wikipedia.org/wiki/Text_editing saved.
# https://en.wikipedia.org/wiki/Machine_translation saved.
# https://en.wikipedia.org/wiki/Text_categorisation saved.
# https://en.wikipedia.org/wiki/Copyright saved.
# https://en.wikipedia.org/wiki/Patent_law saved.
# https://en.wikipedia.org/wiki/Public_domain saved.
# https://en.wikipedia.org/wiki/Website saved.
# https://en.wikipedia.org/wiki/Intranet saved.
# https://en.wikipedia.org/wiki/Design saved.
# https://en.wikipedia.org/wiki/Architecture saved.
# https://en.wikipedia.org/wiki/Scientific_modelling saved.
# https://en.wikipedia.org/wiki/Concept saved.
# https://en.wikipedia.org/wiki/Library saved.
# https://en.wikipedia.org/wiki/Metadata_(computing) saved.
# https://en.wikipedia.org/wiki/Structured_storage saved.
# https://en.wikipedia.org/wiki/Relational_database saved.
# https://en.wikipedia.org/wiki/Information_overload saved.
# https://en.wikipedia.org/wiki/Web_search_engine saved.
# https://en.wikipedia.org/wiki/Information_retrieval_applications saved.
# https://en.wikipedia.org/wiki/Query_string saved.
# https://en.wikipedia.org/wiki/Information_need saved.
# https://en.wikipedia.org/wiki/Relevance saved.
# https://en.wikipedia.org/wiki/Mind_maps saved.
# https://en.wikipedia.org/wiki/Society saved.
# https://en.wikipedia.org/wiki/Knowledge_economy saved.
# https://en.wikipedia.org/wiki/Digital_citizens saved.
# https://en.wikipedia.org/wiki/The_Information_Society saved.
# https://en.wikipedia.org/wiki/Cyberspace saved.
# https://en.wikipedia.org/wiki/Knowledge_representation_and_reasoning saved.
# https://en.wikipedia.org/wiki/Inference saved.
# https://en.wikipedia.org/wiki/Semantic_network saved.
# https://en.wikipedia.org/wiki/Semantics saved.
# https://en.wikipedia.org/wiki/Computer_and_information_science saved.
# https://en.wikipedia.org/wiki/List_of_computer_science_awards#Information_science_awards saved.
# https://en.wikipedia.org/wiki/Outline_of_information_technology saved.
# https://en.wikipedia.org/wiki/Wayback_Machine saved.
# https://en.wikipedia.org/wiki/Tom_Gruber saved.
# https://en.wikipedia.org/wiki/Knowledge_Acquisition saved.
# https://en.wikipedia.org/wiki/CiteSeerX_(identifier) saved.
# https://en.wikipedia.org/wiki/Hdl_(identifier) saved.
# https://en.wikipedia.org/wiki/Shared_decision-making saved.
# https://en.wikipedia.org/wiki/Social_science saved.
# https://en.wikipedia.org/wiki/Outline_of_social_science saved.
# https://en.wikipedia.org/wiki/History_of_the_social_sciences saved.
# https://en.wikipedia.org/wiki/Index_of_sociology_articles saved.
# https://en.wikipedia.org/wiki/Anthropology saved.
# https://en.wikipedia.org/wiki/Archaeology saved.
# https://en.wikipedia.org/wiki/Cultural_anthropology saved.
# https://en.wikipedia.org/wiki/Social_anthropology saved.
# https://en.wikipedia.org/wiki/Physical_anthropology saved.
# https://en.wikipedia.org/wiki/Economics saved.
# https://en.wikipedia.org/wiki/Microeconomics saved.
# https://en.wikipedia.org/wiki/Macroeconomics saved.
# https://en.wikipedia.org/wiki/Econometrics saved.
# https://en.wikipedia.org/wiki/Mathematical_economics saved.
# https://en.wikipedia.org/wiki/Geography saved.
# https://en.wikipedia.org/wiki/Physical_geography saved.
# https://en.wikipedia.org/wiki/Human_geography saved.
# https://en.wikipedia.org/wiki/Technical_geography saved.
# https://en.wikipedia.org/wiki/Integrated_geography saved.
# https://en.wikipedia.org/wiki/History saved.
# https://en.wikipedia.org/wiki/Cultural_history saved.
# https://en.wikipedia.org/wiki/Auxiliary_sciences_of_history saved.
# https://en.wikipedia.org/wiki/Economic_history saved.
# https://en.wikipedia.org/wiki/World_history_(field) saved.
# https://en.wikipedia.org/wiki/Military_history saved.
# https://en.wikipedia.org/wiki/Political_history saved.
# https://en.wikipedia.org/wiki/Social_history saved.
# https://en.wikipedia.org/wiki/Jurisprudence saved.
# https://en.wikipedia.org/wiki/Legal_history saved.
# https://en.wikipedia.org/wiki/List_of_national_legal_systems saved.
# https://en.wikipedia.org/wiki/Public_law saved.
# https://en.wikipedia.org/wiki/Private_law saved.
# https://en.wikipedia.org/wiki/Semiotics saved.
# https://en.wikipedia.org/wiki/Political_science saved.
# https://en.wikipedia.org/wiki/International_relations saved.
# https://en.wikipedia.org/wiki/Comparative_politics saved.
# https://en.wikipedia.org/wiki/Political_philosophy saved.
# https://en.wikipedia.org/wiki/Public_policy saved.
# https://en.wikipedia.org/wiki/Public_administration saved.
# https://en.wikipedia.org/wiki/Abnormal_psychology saved.
# https://en.wikipedia.org/wiki/Cognitive_psychology saved.
# https://en.wikipedia.org/wiki/Developmental_psychology saved.
# https://en.wikipedia.org/wiki/Personality_psychology saved.
# https://en.wikipedia.org/wiki/Social_psychology saved.
# https://en.wikipedia.org/wiki/Criminology saved.
# https://en.wikipedia.org/wiki/Demography saved.
# https://en.wikipedia.org/wiki/Sociology_of_the_Internet saved.
# https://en.wikipedia.org/wiki/Rural_sociology saved.
# https://en.wikipedia.org/wiki/Urban_sociology saved.
# https://en.wikipedia.org/wiki/Business_administration saved.
# https://en.wikipedia.org/wiki/Anthrozoology saved.
# https://en.wikipedia.org/wiki/Area_studies saved.
# https://en.wikipedia.org/wiki/Business_studies saved.
# https://en.wikipedia.org/wiki/Community_studies saved.
# https://en.wikipedia.org/wiki/Development_studies saved.
# https://en.wikipedia.org/wiki/Education saved.
# https://en.wikipedia.org/wiki/Environmental_social_science saved.
# https://en.wikipedia.org/wiki/Environmental_studies saved.
# https://en.wikipedia.org/wiki/Food_studies saved.
# https://en.wikipedia.org/wiki/Gender_studies saved.
# https://en.wikipedia.org/wiki/Global_studies saved.
# https://en.wikipedia.org/wiki/Historical_sociology saved.
# https://en.wikipedia.org/wiki/History_of_technology saved.
# https://en.wikipedia.org/wiki/Human_ecology saved.
# https://en.wikipedia.org/wiki/Media_studies saved.
# https://en.wikipedia.org/wiki/Philosophy_of_science saved.
# https://en.wikipedia.org/wiki/Philosophy_and_economics saved.
# https://en.wikipedia.org/wiki/Philosophy_of_history saved.
# https://en.wikipedia.org/wiki/Philosophy_of_psychology saved.
# https://en.wikipedia.org/wiki/Philosophy_of_social_science saved.
# https://en.wikipedia.org/wiki/Land-use_planning saved.
# https://en.wikipedia.org/wiki/Regional_planning saved.
# https://en.wikipedia.org/wiki/Urban_planning saved.
# https://en.wikipedia.org/wiki/Political_ecology saved.
# https://en.wikipedia.org/wiki/Political_economy saved.
# https://en.wikipedia.org/wiki/Political_sociology saved.
# https://en.wikipedia.org/wiki/Public_health saved.
# https://en.wikipedia.org/wiki/Regional_science saved.
# https://en.wikipedia.org/wiki/Science_studies saved.
# https://en.wikipedia.org/wiki/Quantum_social_science saved.
# https://en.wikipedia.org/wiki/Social_work saved.
# https://en.wikipedia.org/wiki/Vegan_studies saved.
# https://en.wikipedia.org/wiki/List_of_social_science_journals saved.
# https://en.wikipedia.org/wiki/Behavioral_sciences saved.
# https://en.wikipedia.org/wiki/Geisteswissenschaft saved.
# https://en.wikipedia.org/wiki/Human_science saved.
# https://en.wikipedia.org/wiki/Humanities saved.
# https://en.wikipedia.org/wiki/Visualization_(graphics) saved.
# https://en.wikipedia.org/wiki/Biological_data_visualization saved.
# https://en.wikipedia.org/wiki/Chemical_imaging saved.
# https://en.wikipedia.org/wiki/Crime_mapping saved.
# https://en.wikipedia.org/wiki/Flow_visualization saved.
# https://en.wikipedia.org/wiki/Geovisualization saved.
# https://en.wikipedia.org/wiki/Mathematical_diagram saved.
# https://en.wikipedia.org/wiki/Medical_imaging saved.
# https://en.wikipedia.org/wiki/Molecular_graphics saved.
# https://en.wikipedia.org/wiki/Scientific_visualization saved.
# https://en.wikipedia.org/wiki/Social_visualization saved.
# https://en.wikipedia.org/wiki/Software_visualization saved.
# https://en.wikipedia.org/wiki/Technical_drawing saved.
# https://en.wikipedia.org/wiki/User_interface_design saved.
# https://en.wikipedia.org/wiki/Visual_culture saved.
# https://en.wikipedia.org/wiki/Volume_rendering saved.
# https://en.wikipedia.org/wiki/Chart saved.
# https://en.wikipedia.org/wiki/Diagram saved.
# https://en.wikipedia.org/wiki/Engineering_drawing saved.
# https://en.wikipedia.org/wiki/Graph_of_a_function saved.
# https://en.wikipedia.org/wiki/Ideogram saved.
# https://en.wikipedia.org/wiki/Map saved.
# https://en.wikipedia.org/wiki/Photograph saved.
# https://en.wikipedia.org/wiki/Pictogram saved.
# https://en.wikipedia.org/wiki/Plot_(graphics) saved.
# https://en.wikipedia.org/wiki/Sankey_diagram saved.
# https://en.wikipedia.org/wiki/Schematic saved.
# https://en.wikipedia.org/wiki/Skeletal_formula saved.
# https://en.wikipedia.org/wiki/Statistical_graphics saved.
# https://en.wikipedia.org/wiki/Table_(information) saved.
# https://en.wikipedia.org/wiki/Technical_illustration saved.
# https://en.wikipedia.org/wiki/Edmond_Halley saved.
# https://en.wikipedia.org/wiki/Charles-Ren%C3%A9_de_Fourcroy saved.
# https://en.wikipedia.org/wiki/Joseph_Priestley saved.
# https://en.wikipedia.org/wiki/Gaspard_Monge saved.
# https://en.wikipedia.org/wiki/Charles_Dupin saved.
# https://en.wikipedia.org/wiki/Adolphe_Quetelet saved.
# https://en.wikipedia.org/wiki/Andr%C3%A9-Michel_Guerry saved.
# https://en.wikipedia.org/wiki/William_Playfair saved.
# https://en.wikipedia.org/wiki/August_Kekul%C3%A9 saved.
# https://en.wikipedia.org/wiki/Charles_Joseph_Minard saved.
# https://en.wikipedia.org/wiki/Francis_Amasa_Walker saved.
# https://en.wikipedia.org/wiki/John_Venn saved.
# https://en.wikipedia.org/wiki/Oliver_Byrne_(mathematician) saved.
# https://en.wikipedia.org/wiki/Matthew_Henry_Phineas_Riall_Sankey saved.
# https://en.wikipedia.org/wiki/Charles_Booth_(social_reformer) saved.
# https://en.wikipedia.org/wiki/John_Snow saved.
# https://en.wikipedia.org/wiki/Florence_Nightingale saved.
# https://en.wikipedia.org/wiki/Karl_Wilhelm_Pohlke saved.
# https://en.wikipedia.org/wiki/Toussaint_Loua saved.
# https://en.wikipedia.org/wiki/Francis_Galton saved.
# Crawling complete!
